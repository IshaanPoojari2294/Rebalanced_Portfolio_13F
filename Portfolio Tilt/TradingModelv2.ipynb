# %%
'''
Top 10th percentile of stocks in each quarter based on portfolio tilt:
2001-12-31 00:00:00: ['C', 'NXTL', 'TWX', 'EIX', 'LNC', 'FE', 'ELN', 'T', 'T', 'PVN', 'IBM', 'PVN', 'COST', 'VIAV', 'PFE', 'TGNA', 'HD', 'STI', 'FCEL', 'SFE', 'MRK', 'AKAM', 'FDC', 'DD', 'CEM', 'BEV', 'GPS', 'NEOL', 'FE', 'INTC', 'WFC', 'JAVA', 'MO', 'EVRG', 'INTC', 'DD', 'DELL', 'CCI', 'FALC', 'ITWO', 'BLS', 'DOV', 'MTB', 'VIAV', 'SGP', 'DNB', 'ITWO', 'SILI', 'PARA', 'PACW', 'DD', 'TXN', 'DIS', 'ODP', 'TT', 'JNY', 'JPM', 'MCD', 'AWE', 'NHI', 'PARA', 'HRB', 'BA', 'WPO', 'PVN', 'G', 'TZH', 'CMTN', 'DNB', 'AMAT', 'OSI', 'QQQ', 'Q', 'XLNX', 'PAYX', 'ALL', 'MCO', 'TGT', 'GL', 'GPS', 'MXIM', 'CRAY', 'WM']
2002-09-30 00:00:00: ['WINT', 'C', 'C', 'T', 'T', 'AIG', 'PCG', 'INTC', 'PFE', 'ADP', 'TGNA', 'BKS', 'STI', 'ETS', 'COST', 'CSCO', 'FRTX', 'INTC', 'FALC', 'DIS', 'JNJ', 'MCD', 'AMAT', 'S', 'FRTX', 'BEV', 'MDC', 'SGP', 'GPS', 'SPY', 'ACF', 'SILI', 'MO', 'WFC', 'TXN', 'POG', 'LVLT', 'KRB', 'MRK', 'PACW', 'MTB', 'RTN', 'ODP', 'COP', 'PLX', 'AXP', 'OMC', 'LTC', 'DNB', 'ALD', 'CSCO', 'JCI', 'ABT', 'DOV', 'ORCL', 'JNY', 'HP', 'GPS', 'BMY', 'RTN', 'S', 'TT', 'WPO', 'WB', 'G', 'ONE', 'JCI', 'HRB', 'EYE', 'MDT', 'WFC', 'BMY', 'JPM', 'QQQ', 'VVI', 'PACW', 'BAC', 'USB', 'JAVA', 'FITB', 'DG', 'DNB', 'BKR', 'MCO', 'ACN', 'EIX']
2002-12-31 00:00:00: ['PFE', 'AIG', 'INTC', 'INTC', 'T', 'HD', 'MRK', 'PCG', 'AMGN', 'MSI', 'C', 'ADP', 'FDC', 'AXP', 'EIX', 'TGNA', 'ODP', 'SPY', 'DELL', 'FRTX', 'STI', 'CCI', 'GPS', 'COST', 'PNC', 'FRTX', 'TGT', 'AMAT', 'WINT', 'KO', 'FALC', 'T', 'ISIL', 'PCG', 'ODP', 'NOK', 'CMCSK', 'CSCO', 'WTW', 'DIS', 'HWM', 'SANM', 'CE', 'RTN', 'ADCT', 'MTB', 'SWKS', 'EMC', 'BBY', 'DNB', 'AYE', 'PARA', 'WTW', 'RRI', 'XOM', 'DOV', 'PACW', 'JNY', 'CNH', 'GOLD', 'HPQ', 'POG', 'SLAB', 'JCI', 'THC', 'DISH', 'HD', 'TT', 'SANM', 'XJT', 'MU', 'TQNT', 'S', 'WPO', 'MET', 'FDX', 'MU', 'THG', 'CDWC', 'RIG', 'HRB', 'SEBL']
2003-03-31 00:00:00: ['FRTX', 'T', 'PFE', 'FRTX', 'C', 'INTC', 'MSFT', 'TWX', 'WINT', 'DUK', 'LVLT', 'MSFT', 'MRK', 'PCG', 'FDC', 'T', 'AXP', 'DELL', 'MS', 'PARA', 'C', 'ADP', 'TGNA', 'INTC', 'EIX', 'BMY', 'STI', 'COST', 'GPS', 'NOK', 'CMTN', 'WM', 'FALC', 'THC', 'TXN', 'CMCSK', 'HPQ', 'GS', 'OEI', 'MCD', 'QQQ', 'WM', 'JCI', 'SANM', 'AXP', 'DNB', 'MTB', 'CMCSK', 'FDX', 'MET', 'AYE', 'NOC', 'KO', 'CCU', 'DOV', 'NOC', 'TT', 'DISH', 'GS', 'QMCO', 'LU', 'MXIM', 'OVV', 'LLTC', 'HAL', 'DNB', 'GDW', 'HRB', 'OSI', 'MU', 'VTR', 'WPO', 'DIA', 'FE']
2003-06-30 00:00:00: ['EIX', 'PFE', 'NEOL', 'C', 'BBX', 'LVLT', 'INTC', 'DUK', 'MSFT', 'DELL', 'C', 'MU', 'TWX', 'SFE', 'T', 'MRK', 'CMTN', 'FDC', 'AXP', 'INTC', 'MS', 'JNP', 'FALC', 'ADP', 'TGNA', 'WM', 'COST', 'BBX', 'TWX', 'STI', 'GPS', 'AWE', 'EMC', 'HUM', 'WYE', 'THC', 'HCA', 'AYE', 'WM', 'IP', 'FDX', 'C', 'CMCSK', 'QQQ', 'MET', 'JCI', 'NOK', 'TWX', 'INTC', 'FL', 'T', 'WY', 'MTB', 'FNFG', 'A', 'NOC', 'GOLD', 'NTZ', 'SDS', 'DNB', 'THG', 'IDT', 'QMCO', 'PACW', 'TXN', 'CE', 'TRI', 'LU', 'DISH', 'CNXT', 'HAL', 'DOV', 'GNTA', 'PFS']
2003-09-30 00:00:00: ['EIX', 'PFE', 'TWX', 'MU', 'SFE', 'INTC', 'BBX', 'LVLT', 'DUK', 'MRK', 'C', 'DELL', 'MRK', 'C', 'BN', 'INTC', 'CMTN', 'FDC', 'BAC', 'SAF', 'MS', 'ADP', 'NOK', 'TGNA', 'THC', 'CCI', 'FALC', 'WM', 'C', 'STI', 'SANM', 'FL', 'IP', 'COST', 'MET', 'GPS', 'HCA', 'FDX', 'TXN', 'JCI', 'WM', 'NTZ', 'WY', 'ORCL', 'AFR', 'INO', 'A', 'IGEN', 'MTB', 'WC', 'EDS', 'GOLD', 'RBBN', 'SCMR', 'BP', 'WRC', 'DNB', 'MDLZ', 'DOV', 'NOC', 'LMT', 'UCI', 'BN', 'LU', 'XEL', 'GNTA', 'JNPR', 'HAL', 'FE', 'IDT', 'TT', 'WRC']
2003-12-31 00:00:00: ['INTC', 'PFE', 'GE', 'INTC', 'VGR', 'DELL', 'CNX', 'MEE', 'HRY', 'HES', 'BBX', 'MSFT', 'FALC', 'C', 'AL', 'NVAL', 'FDC', 'MRK', 'JAVA', 'FL', 'ADP', 'MS', 'DD', 'TGNA', 'GPS', 'CMTN', 'C', 'STI', 'BMY', 'MT', 'HCA', 'COST', 'WC', 'WM', 'TWX', 'CCI', 'PD', 'MSI', 'XOM', 'NOK', 'MT', 'XRX', 'NTZ', 'S', 'KO', 'FCX', 'INO', 'MTB', 'WM', 'CNX', 'IP', 'SGP', 'LTS', 'IGEN', 'DOV', 'AWE', 'WY', 'A', 'RRI', 'MEE', 'MO', 'UVN', 'NOC', 'IPCC', 'TT', 'EDS', 'PMI', 'ATAR', 'GOLD', 'PXP', 'WNG', 'SAF', 'CNO', 'CNXT', 'NMGC']
2004-03-31 00:00:00: ['DB', 'X', 'PFE', 'OVV', 'MSI', 'INTC', 'INTC', 'MEE', 'XOMA', 'C', 'MO', 'X', 'FDC', 'DELL', 'IMCL', 'MS', 'JAVA', 'TGNA', 'C', 'DIS', 'WM', 'GPS', 'YUM', 'STI', 'MT', 'FL', 'COST', 'VGR', 'HCA', 'PFE', 'ALE', 'HRY', 'WM', 'FBF', 'TWX', 'CMCSK', 'PARA', 'CMX', 'DD', 'DVN', 'ISG', 'NTLI', 'FCX', 'AW', 'PD', 'MTB', 'HD', 'EIX', 'IP', 'NVAL', 'PNX', 'PKX', 'UVN', 'WFC', 'A', 'KO', 'MHS', 'STX', 'TT', 'WC', 'SAF', 'UNM', 'MT', 'MHS', 'SGP', 'CNXT', 'GOLD', 'QMCO', 'NUE']
2004-06-30 00:00:00: ['PRSO', 'C', 'DB', 'PFE', 'PRSO', 'PARA', 'VGR', 'INTC', 'NTLI', 'HRY', 'MSFT', 'XOMA', 'MO', 'ISG', 'FDC', 'VVI', 'PKX', 'INTC', 'C', 'CNX', 'MS', 'NVAL', 'DELL', 'FALC', 'JAVA', 'TGNA', 'GPS', 'ALE', 'COST', 'STI', 'HCA', 'CMCSK', 'LVLT', 'MHS', 'NRG', 'MHS', 'LTS', 'MTB', 'SAF', 'JPM', 'PFE', 'AKS', 'TT', 'MO', 'HWM', 'DRI', 'C', 'TT', 'OVV', 'A', 'WC', 'CVX', 'KO', 'ADP', 'STLD', 'MEE', 'STFC', 'AGY', 'CCI', 'TGT', 'WFC', 'MU', 'WPO', 'ZBH', 'WM', 'PARA', 'SVM', 'GOLD', 'HRB', 'GDW']
2004-09-30 00:00:00: ['CVX', 'PFE', 'VGR', 'INTC', 'C', 'C', 'PFE', 'MO', 'COP', 'NRG', 'CCI', 'FDC', 'NVAL', 'WC', 'FALC', 'MS', 'X', 'BR', 'APA', 'TGNA', 'BNK', 'DELL', 'COST', 'STI', 'KO', 'MRK', 'WM', 'TWX', 'LVLT', 'GPS', 'CMCSK', 'NTY', 'XOMA', 'HCA', 'ORCL', 'COX', 'CFC', 'STFC', 'INTC', 'WM', 'JPM', 'JAVA', 'MEE', 'X', 'MTB', 'AW', 'JNPR', 'HWM', 'MRO', 'ALD', 'TT', 'WMT', 'DVN', 'LTS', 'AMGN', 'TT', 'PMI', 'PCG', 'USB', 'MS', 'WNG', 'EMR', 'GNW', 'AZO', 'STX', 'PLKI', 'QNTA', 'KMG']
2004-12-31 00:00:00: ['PFE', 'NCTY', 'IMCL', 'C', 'MSFT', 'XOM', 'JCI', 'HLYW', 'MS', 'NXTL', 'ISG', 'RRI', 'MSFT', 'MO', 'MSFT', 'KO', 'S', 'WB', 'BUD', 'FDC', 'DUK', 'PFE', 'C', 'STI', 'IPS', 'MCIP', 'COST', 'TGNA', 'NTY', 'VGR', 'WFC', 'GPS', 'GDW', 'CMCSK', 'JPM', 'CCI', 'GNW', 'SPRT', 'LVLT', 'JAVA', 'XOMA', 'BP', 'LEU', 'SDS', 'PCG', 'STFC', 'WYE', 'EBAY', 'NVAL', 'WM', 'MSI', 'F', 'MTB', 'QCOM', 'IOC', 'TWX', 'HCA', 'MDT', 'TT', 'X', 'WNG', 'NXTL', 'WM', 'GEAC', 'GEN', 'MU', 'BNI', 'WTW', 'HSBC', 'NWS', 'TT', 'PLKI', 'IDT', 'NTLI', 'MS', 'S', 'HAFC', 'JPM', 'JNPR', 'EA', 'GS', 'JCI', 'GEN', 'QNTA', 'CCU']
2005-03-31 00:00:00: ['C', 'GE', 'C', 'KMG', 'PG', 'MSFT', 'MSI', 'LVLT', 'TRQ', 'SNDK', 'TFCF', 'HLYW', 'IMCL', 'PFE', 'S', 'WMT', 'FDC', 'AXP', 'CCI', 'STI', 'HAL', 'PARA', 'COST', 'TGNA', 'HAFC', 'GPS', 'CMCSK', 'PCG', 'PHH', 'STFC', 'IPS', 'PG', 'MS', 'CVX', 'WM', 'GEAC', 'C', 'CCJ', 'S', 'TWX', 'CVX', 'DUK', 'BUD', 'BNI', 'IOC', 'NXTL', 'PFE', 'MTB', 'GRMN', 'BZH', 'VGR', 'TT', 'PHH', 'WM', 'FSL', 'KO', 'GTI', 'NVAL', 'FICC', 'VVI', 'WNG', 'TT', 'PFE', 'KMG', 'ORCL', 'SEBL', 'GEN', 'WB', 'SPRT', 'QNTA', 'IDT', 'T', 'JAVA', 'STT', 'BBY', 'WLL', 'DD', 'BP', 'JNPR', 'ATAR', 'MO', 'OPMR', 'SINA', 'S', 'SMSC', 'GNW', 'CRK', 'VRTS', 'MS', 'OI', 'IFOX', 'CMX', 'SVM', 'FSL', 'MERC']
2005-06-30 00:00:00: ['C', 'GE', 'MSFT', 'ALD', 'IBM', 'TWX', 'ALD', 'PG', 'JCI', 'NVAL', 'MSI', 'TRQ', 'HD', 'S', 'JCI', 'CCI', 'MSFT', 'DIS', 'A', 'C', 'WMT', 'WMT', 'CSCO', 'PG', 'EMC', 'CVX', 'MEDI', 'DD', 'LVLT', 'ALD', 'NOK', 'PARA', 'SNDK', 'FDC', 'COP', 'PFE', 'MS', 'STI', 'LOW', 'UNH', 'ALD', 'ORCL', 'JPM', 'COST', 'PXD', 'IPS', 'OVV', 'AMTD', 'SPRT', 'UTSI', 'GEN', 'JAVA', 'TGNA', 'GPS', 'XOMA', 'CMCSK', 'ELV', 'MLNM', 'TWX', 'WMT', 'GS', 'DUK', 'CAH', 'JCI', 'SU', 'MU', 'CMX', 'PHH', 'EYE', 'COP', 'CRK', 'MS', 'T', 'WB', 'MRK', 'NWS', 'BEAM', 'SIRI', 'LXK', 'KO', 'AMTD', 'KO', 'MTB', 'MRK', 'PFE', 'BAC', 'S', 'GEN', 'TT', 'JCI', 'APA', 'CVS', 'EYE', 'WM', 'GEAC', 'WFC', 'HCBK', 'GS', 'CNX', 'TT', 'MT', 'SLM', 'S', 'STFC', 'NEM', 'EXC', 'EDS']
2005-09-30 00:00:00: ['C', 'ANX', 'CVX', 'MSFT', 'GE', 'GE', 'PFE', 'ALD', 'PG', 'MSFT', 'ALD', 'C', 'BAC', 'MSFT', 'JCI', 'MO', 'HD', 'PDS', 'TWX', 'ABT', 'MSFT', 'ORCL', 'PFE', 'S', 'MS', 'WMT', 'ORCL', 'ORCL', 'PA', 'WBA', 'S', 'MSI', 'SNDK', 'ODP', 'FDC', 'ALD', 'LOW', 'WMT', 'IPS', 'TRQ', 'NVAL', 'STI', 'T', 'OVV', 'CCL', 'GLD', 'ALD', 'CVS', 'EMC', 'COST', 'S', 'GEN', 'CSCO', 'DUK', 'SPRT', 'A', 'CAH', 'TGNA', 'JAVA', 'FMD', 'CMCSK', 'XOMA', 'GPS', 'KO', 'AXP', 'TT', 'PHH', 'NEM', 'VLO', 'JCI', 'UPS', 'LVLT', 'HAL', 'S', 'GEN', 'NWS', 'GLW', 'MTB', 'NTLI', 'TT', 'KRB', 'LMT', 'LXK', 'SU', 'WM', 'GNW', 'WB', 'BJS', 'AMAT', 'PKX', 'HET', 'HRB', 'ELV', 'SEBL', 'BBY', 'PHH', 'CHL', 'SLM', 'GEN', 'GEAC', 'GDW', 'VIAV', 'WMT', 'NEM', 'T', 'SOV', 'MEDI', 'EXC', 'BBY', 'ELV', 'FE', 'OXY', 'DNB', 'GEN', 'HCBK']
2006-03-31 00:00:00: ['C', 'GE', 'MSFT', 'MCD', 'AIG', 'ABIO', 'GE', 'MSFT', 'ALD', 'MSI', 'ALD', 'C', 'C', 'TWX', 'IBM', 'MO', 'JCI', 'GLD', 'S', 'PFE', 'JNJ', 'L', 'ANX', 'HSH', 'DD', 'PA', 'S', 'JCI', 'ALD', 'ABIO', 'ALD', 'BC', 'PDS', 'XOMA', 'OVV', 'JCI', 'JAVA', 'HD', 'MRK', 'CSCO', 'BLS', 'KO', 'INTC', 'QCOM', 'UNH', 'MSFT', 'ORCL', 'IPS', 'CVS', 'TRQ', 'JCI', 'SPRT', 'MSFT', 'PRU', 'GEN', 'UPS', 'USB', 'GNW', 'OVV', 'OVV', 'SLB', 'WMB', 'WM', 'SGP', 'ICO', 'AT', 'MT', 'ABT', 'CSCO', 'IBM', 'IBM', 'GDW', 'TWX', 'TWX', 'LYV', 'TFCF', 'CA', 'LOW', 'CHL', 'VIAB', 'NWS', 'ELV', 'AMT', 'UNH', 'CA', 'WTW', 'SPGI', 'GOLD', 'HCBK', 'NEM', 'MSFT', 'MSFT', 'S', 'CA', 'JAVA', 'GDT', 'DNA', 'WM', 'FE', 'STI', 'AMGN', 'PGN', 'CMCSK', 'WFC', 'STJ', 'SLM', 'SNDK', 'ITW', 'COST', 'TX', 'ABT', 'FDC', 'PFG', 'HRB', 'JCI', 'F', 'SMSC', 'AXP', 'AXP', 'UTSI', 'VZ', 'VZ', 'SLM', 'MU', 'BSX', 'LUV', 'BRCM', 'WTW', 'HD', 'HD', 'WMB', 'BP', 'BP', 'GEN', 'GEN', 'MHS', 'CCJ', 'STX', 'AT', 'FICC', 'WYE', 'WYE', 'QQQ', 'GPS', 'DB', 'DB']
2006-06-30 00:00:00: ['C', 'GE', 'MSFT', 'MSI', 'MSFT', 'ABIO', 'ABIO', 'AIG', 'ABIO', 'MSFT', 'GE', 'MO', 'TWX', 'WEN', 'CSCO', 'JCI', 'PA', 'MO', 'IBM', 'MSFT', 'PDS', 'CSCO', 'HSH', 'BKS', 'UNH', 'ALD', 'ABIO', 'ALD', 'XRX', 'OVV', 'ABIO', 'JAVA', 'WBA', 'MSFT', 'BLS', 'S', 'ANX', 'OVV', 'JCI', 'ABIO', 'MSI', 'WEN', 'KO', 'EMC', 'CVS', 'HD', 'AT', 'EBAY', 'HSH', 'MT', 'WM', 'QCOM', 'XOMA', 'WMB', 'UPS', 'COP', 'ACN', 'VIAB', 'S', 'CMX', 'NOK', 'CAH', 'AT', 'JAVA', 'TRI', 'WFC', 'STAR', 'TGT', 'DHI', 'WM', 'MHS', 'SIZ', 'GEN', 'AMP', 'DD', 'CSCO', 'HCBK', 'ITW', 'TRB', 'PARA', 'AEP', 'ALD', 'AT', 'LOW', 'TPR', 'WTW', 'JCI', 'MO', 'EGO', 'ALD', 'STI', 'TGT', 'GRMN', 'GEN', 'NOK', 'CAH', 'WMB', 'GPS', 'GNW', 'COST', 'FDC', 'CVA', 'DHI', 'PD', 'GLW', 'MHS', 'KLAC', 'HCBK', 'BEN', 'SPRT', 'SOV', 'DR', 'FDC', 'USB', 'MU', 'HAL', 'F', 'TPR', 'PD', 'LRCX', 'JCI', 'CSCO', 'TV', 'WTW', 'CAA', 'AL', 'ASML', 'RFMD', 'BLU', 'AT', 'PHG', 'APC', 'CTCM']
2007-12-31 00:00:00: ['C', 'GE', 'NCTY', 'MSI', 'QID', 'MSFT', 'TGT', 'AIG', 'MSFT', 'GS', 'CSCO', 'GS', 'DUK', 'BIIB', 'CCI', 'HSH', 'KO', 'CVS', 'BAC', 'EMC', 'BG', 'TGT', 'WBA', 'MHS', 'COV', 'CME', 'BNI', 'CAH', 'BEAS', 'QQQ', 'IWM', 'FIS', 'UNH', 'NCTY', 'LDOS', 'MHS', 'GLRE', 'UPS', 'BG', 'AAPL', 'BKS', 'CCI', 'SE', 'HD', 'MHS', 'NTR', 'RTX', 'KMX', 'TRI', 'JCI', 'TIN', 'LOW', 'DVN', 'DFS', 'MHS', 'DTV', 'JCI', 'HSBC', 'AEO', 'SINA', 'RRI', 'UST', 'PRDO', 'BNI', 'COST', 'WMT', 'VMC', 'GSK', 'BSC', 'FDX', 'ESRX', 'APA', 'STI', 'AXAS', 'NSC', 'MSCI', 'CCU', 'HET', 'HWM', 'JNPR', 'ABI', 'COV', 'NRG', 'ANX', 'CMCSK', 'DKS', 'CI', 'MSI', 'AMAT', 'BBWI', 'MKL', 'AMP', 'TT', 'BMRN', 'SRX', 'FOR', 'SUN', 'TPR', 'TDC', 'TK', 'CCI', 'QQQ', 'NSH', 'MSM', 'SNY', 'CME', 'EXP', 'NTRI', 'ICE', 'TT', 'GRBK', 'WTM', 'LDOS', 'MA', 'GFG', 'HOV', 'TT', 'TGNA', 'MBI', 'GRBK', 'ESRX', 'MWV', 'WSC', 'FAF', 'LGND', 'CMCSK', 'TNK', 'WLT', 'URS', 'ROK', 'IRM', 'PROJ', 'MCY', 'TT', 'MSCI', 'UFS', 'MTB', 'CYBX', 'IBN', 'FI', 'DOX', 'UNP', 'PCS', 'EMN', 'HMA', 'LGND', 'AKS', 'ARII', 'VXRT', 'FOR', 'XLF', 'PMC', 'NKE', 'WCC', 'USBE', 'TLAB', 'PAC', 'SBAC', 'MA', 'BYON', 'GCO', 'LORL', 'INFY', 'UTSI', 'EIG', 'TIE', 'BKNG', 'KMX', 'WBC', 'EMC', 'WNS', 'GT', 'TNL', 'NSR', 'FAST', 'KMPR', 'M', 'FUR', 'GFG']
2008-03-31 00:00:00: ['GE', 'AIG', 'WWR', 'QID', 'MSI', 'KO', 'DUK', 'MT', 'TGT', 'BEL', 'CCI', 'PFE', 'ELV', 'QCOM', 'WBA', 'BIIB', 'HOV', 'CSCO', 'ORCL', 'EMC', 'ELV', 'CCI', 'TPR', 'MON', 'SE', 'TEL', 'HSH', 'CNQ', 'WEN', 'BAC', 'BG', 'HSBC', 'BKS', 'WYE', 'COV', 'TGT', 'MOS', 'AMGN', 'QCOM', 'HD', 'NTR', 'BEAS', 'EBAY', 'IBM', 'QCOM', 'GSK', 'TWX', 'BCE', 'CVC', 'CME', 'LDOS', 'ACL', 'HPQ', 'MO', 'MFIC', 'LDOS', 'NBR', 'ACL', 'DFS', 'GLW', 'TRA', 'MOS', 'WTM', 'JNJ', 'GLD', 'NOK', 'ACN', 'MKL', 'X', 'NLC', 'VZ', 'AMAT', 'UNH', 'TEL', 'UPS', 'SWN', 'HWM', 'SPY', 'WFC', 'ADBE', 'CIM', 'GLRE', 'WEN', 'HD', 'CAH', 'BG', 'BIIB', 'CM', 'JRJC', 'TWC', 'WFR', 'COV', 'DUK', 'FHN', 'NYT', 'UNH', 'DTV', 'CMCSK', 'DD', 'WSC', 'NTRS', 'GS', 'GPS', 'EMKR', 'CSE', 'AGN', 'CAA', 'WWY', 'BKR', 'FCX', 'MON', 'WOLF', 'VLO', 'USB', 'FMCN', 'DIS', 'LOW', 'TIN', 'MCY', 'ANX', 'MBI', 'ETFC', 'EXPE', 'APA', 'BN', 'BK', 'V', 'ELV', 'AMGN', 'PM', 'PNX', 'DELL', 'SWY', 'UNH', 'DD', 'TDC', 'KFN', 'HNT', 'RRI', 'RWT', 'ORCL', 'WYNN', 'COST', 'DELL', 'MBI', 'ADI', 'ELV', 'HPQ', 'ROK', 'EBAY', 'NSC', 'CCU', 'MTG', 'FOR', 'CROX', 'UST', 'DKS', 'BKNG']
2008-06-30 00:00:00: ['GE', 'BIIB', 'AIG', 'GE', 'TGT', 'C', 'DUK', 'KO', 'BEL', 'LVLT', 'BB', 'MON', 'MSFT', 'BMY', 'PFE', 'JPM', 'JNJ', 'CCI', 'T', 'IMCL', 'SLB', 'UNH', 'CCI', 'ELV', 'ORCL', 'WBA', 'CSCO', 'QCOM', 'ELV', 'TIN', 'VZ', 'SLB', 'SE', 'TEL', 'BG', 'BAC', 'SPY', 'COV', 'TGT', 'XTO', 'ZION', 'AMSC', 'TWC', 'ANX', 'BAC', 'GS', 'HWM', 'GLW', 'WFC', 'FOR', 'HOV', 'TAOP', 'EMC', 'CNQ', 'PAYX', 'CYBX', 'HSBC', 'CSCO', 'IPI', 'V', 'ACL', 'TPR', 'AMAT', 'UTSI', 'MON', 'IPI', 'LDOS', 'CRK', 'ACL', 'COV', 'MDLZ', 'STT', 'LO', 'PFE', 'MOS', 'AMSC', 'SPRT', 'GOLD', 'ADBE', 'GOLD', 'CME', 'GLW', 'LDG', 'EBAY', 'SPY', 'CCL', 'BG', 'UNP', 'HAL', 'UPS', 'GG', 'NOV', 'PLG', 'CNQ', 'HD', 'FDX', 'MBI', 'PNX', 'EXC', 'HSBC', 'ENZN', 'ARII', 'NWS', 'NTRS', 'S', 'COST', 'HON', 'AAPL', 'SWY', 'NOK', 'WTM', 'S', 'MHK', 'MOS', 'WMT', 'BN', 'UNH', 'BKNG', 'NEM', 'BKS', 'TSM', 'FOR', 'LOW', 'BRCM', 'MEE', 'CME', 'MKL', 'QCOM', 'JEF', 'SNV', 'NYT', 'NM', 'HK', 'MTL', 'COST', 'COV', 'HOT', 'DSTI', 'NSC']
2008-09-30 00:00:00: ['GE', 'AIG', 'BIIB', 'NCTY', 'EMC', 'CCI', 'MSFT', 'AIG', 'KO', 'AIG', 'MSFT', 'JPM', 'GE', 'PFE', 'BAC', 'KGC', 'CCI', 'BMY', 'JPM', 'JPM', 'T', 'HOV', 'HPQ', 'CCI', 'CCI', 'SRS', 'SRS', 'VZ', 'TIN', 'ELV', 'AMP', 'CCI', 'FRO', 'MER', 'C', 'BAC', 'HPQ', 'T', 'TWC', 'ABT', 'CSCO', 'LGF', 'TGT', 'USD', 'GS', 'GS', 'RF', 'BAX', 'WYE', 'NOC', 'BUD', 'BK', 'CMA', 'TGT', 'BG', 'MS', 'MHS', 'MI', 'HSBC', 'MHS', 'LDOS', 'SLB', 'TPR', 'FOR', 'MOS', 'SU', 'CYBX', 'C', 'BA', 'EXC', 'PCP', 'AMX', 'ANX', 'XTO', 'COV', 'CME', 'CVS', 'ZION', 'COV', 'TMO', 'AMAT', 'LO', 'ITT', 'HD', 'CVS', 'UPS', 'VIAB', 'ACL', 'ENZN', 'HBAN', 'ACL', 'S', 'CCI', 'MDC', 'WTM', 'ETR', 'AGN', 'ARII', 'AMAT', 'STI', 'LOW', 'NTR', 'NTR', 'NLY', 'NLY', 'BEL', 'PBR', 'SCI', 'APA', 'QCOM', 'UNH', 'WMT', 'UST', 'STAR', 'ETR']
2008-12-31 00:00:00: ['GE', 'BIIB', 'NCTY', 'TGT', 'SRS', 'SRS', 'MSFT', 'KO', 'BMY', 'SVU', 'ORCL', 'T', 'AIG', 'JNJ', 'WFC', 'BNI', 'MER', 'VZ', 'JPM', 'GLW', 'PM', 'DD', 'HPQ', 'CSCO', 'NSC', 'SKF', 'TWC', 'GD', 'AXP', 'UNP', 'LGF', 'ROH', 'GLD', 'XTO', 'SCHW', 'AMT', 'AXP', 'GS', 'WMT', 'MO', 'BAC', 'DAC', 'EXC', 'BA', 'CYBX', 'BNI', 'CVX', 'DVN', 'OXY', 'XTO', 'MCK', 'CCL', 'APA', 'MHS', 'GLD', 'V', 'MHS', 'EMC', 'HD', 'MOS', 'MON', 'JCI', 'ALX', 'TXN', 'GFG', 'BG', 'ATVI', 'HD', 'AMX', 'WEN', 'COP', 'PNX', 'ENZN', 'EA', 'UPS', 'PRU', 'UST', 'UNH', 'ETR', 'FWLT', 'MRO', 'HSBC', 'COV', 'LOW', 'JCI', 'JASO', 'WDC', 'LIFE', 'APC', 'LOW', 'UNH', 'TPR', 'NOC', 'CME', 'LO']
2009-03-31 00:00:00: ['GE', 'BIIB', 'TGT', 'MSFT', 'SRS', 'KO', 'MSFT', 'BMY', 'SGP', 'C', 'YUM', 'PFE', 'NBR', 'T', 'GLD', 'WYE', 'HPQ', 'AMX', 'COF', 'NRG', 'PG', 'BAC', 'CHL', 'PEP', 'ODP', 'JNJ', 'ORCL', 'KO', 'V', 'STI', 'BKNG', 'GD', 'SVU', 'PFE', 'CSCO', 'GLW', 'PM', 'CVC', 'PEP', 'WBA', 'GLD', 'LGF', 'GLD', 'UNH', 'CNQ', 'XL', 'OXY', 'MON', 'BAC', 'XTO', 'LMT', 'XTO', 'HD', 'GLD', 'ANX', 'GT', 'EMC', 'BA', 'SHW', 'USO', 'UPS', 'NCTY', 'ATVI', 'FITB', 'AGN', 'EXC', 'MRO', 'TDG', 'ROH', 'WEN', 'DD', 'CME', 'ENZN', 'LOW', 'BNI', 'TBT', 'UNH', 'GLD', 'LMDIA', 'EIX', 'NLY', 'JNK', 'PEG', 'XOM', 'AXP']
2009-06-30 00:00:00: ['BIIB', 'GE', 'JPM', 'MCD', 'DRYS', 'GE', 'UNG', 'KO', 'TGT', 'XOM', 'TRV', 'ORCL', 'BMY', 'MSFT', 'MSFT', 'SRS', 'MSFT', 'ODP', 'SGP', 'HPQ', 'PFE', 'COF', 'MON', 'HPQ', 'AXP', 'WFC', 'MO', 'NRG', 'GD', 'BAC', 'BAC', 'BA', 'BAC', 'ADP', 'UNH', 'USB', 'LGF', 'WFC', 'STI', 'QCOM', 'RF', 'TGT', 'XL', 'XTO', 'ANX', 'WU', 'APC', 'CNW', 'KO', 'ENZN', 'MMM', 'FITB', 'NOC', 'GLD', 'HD', 'GT', 'SWN', 'HPQ', 'UPS', 'PGR', 'DELL', 'LMDIA', 'TRV', 'UNP', 'HSBC', 'CSCO', 'UNH', 'QCOM', 'EBAY', 'LOW', 'XTO', 'LMDIA', 'STI', 'GEN', 'PCP', 'COV', 'COF', 'DOX', 'AGN', 'ELV', 'QCOM', 'TEL', 'ETFC', 'GLD', 'JPM', 'MS', 'ARII', 'PBG', 'ECL', 'CB', 'NUE', 'CCL', 'CB', 'Q', 'MRO', 'WMT', 'FITB', 'COST', 'GLD', 'BDX', 'JAVA']
2009-09-30 00:00:00: ['BIIB', 'GE', 'TRV', 'C', 'DRYS', 'KO', 'GE', 'MCD', 'MCD', 'BMY', 'BAC', 'MSFT', 'ORCL', 'WYE', 'PM', 'ADP', 'XOM', 'C', 'HPQ', 'QCOM', 'MSFT', 'KO', 'HD', 'LGF', 'BAC', 'WU', 'MSFT', 'MSI', 'WBA', 'PFE', 'EMC', 'CAH', 'PG', 'MON', 'ANX', 'APC', 'DTV', 'MSFT', 'JPM', 'GS', 'ELV', 'QCOM', 'PG', 'ENZN', 'NOC', 'ORCL', 'MSI', 'TGT', 'CXW', 'GOLD', 'LMDIA', 'ODP', 'LMDIA', 'PCP', 'HD', 'TFC', 'EA', 'TPR', 'UPS', 'AGN', 'JCI', 'ARII', 'AAPL', 'WFC', 'ACL', 'TEL', 'HIG', 'SWN', 'AET', 'GLD', 'ACL', 'AMX', 'RSG', 'WTM', 'PBG', 'COF', 'JAVA', 'JCI', 'TRV', 'AON', 'LOW', 'MMM', 'UNH', 'CTXS', 'FITB', 'ELV', 'GR', 'KR', 'EA', 'RX', 'CVC', 'XTO', 'LGF', 'PNX', 'MCD', 'GLD', 'ADP', 'NRG', 'ELV', 'BB', 'TDC', 'MCD', 'COST', 'EBAY', 'PBI', 'ETFC', 'MV', 'GOLD', 'GSK', 'GLRE', 'HBAN', 'CFN', 'BDX', 'XL', 'NKE', 'GENZ', 'NSC', 'ETFC', 'CX', 'HIG', 'QRTEA', 'XTO', 'BK', 'PAS', 'PTV', 'AAPL', 'FLIR', 'AGN', 'STI', 'SEE', 'URS', 'AWK', 'STI', 'CMCSK', 'CB', 'MR', 'EL']
2009-12-31 00:00:00: ['DRYS', 'BIIB', 'TRV', 'GE', 'ADP', 'HPQ', 'CIT', 'MSFT', 'PFE', 'MSI', 'HPQ', 'MCD', 'XOM', 'HPQ', 'KO', 'TRV', 'QCOM', 'ANX', 'BMY', 'XOM', 'JPM', 'WFC', 'PFE', 'YUM', 'BAC', 'BAC', 'JPM', 'TTWO', 'QCOM', 'LGF', 'MON', 'GOLD', 'WU', 'TEVA', 'DTV', 'BAC', 'CXW', 'CVS', 'ENZN', 'PG', 'PEP', 'MMM', 'MSFT', 'ACN', 'WFC', 'EMC', 'H', 'GOLD', 'XRX', 'GS', 'DTV', 'ODP', 'DIS', 'WFC', 'TFC', 'HD', 'WFC', 'CMCSA', 'GLD', 'AMAT', 'TGT', 'GLW', 'EBAY', 'CMCSA', 'UPS', 'OXY', 'GLRE', 'LMT', 'UNH', 'SWN', 'MSFT', 'COF', 'TDC', 'WTW', 'LOW', 'MMM', 'MS', 'GLD', 'SPLS', 'TRV', 'GOLD', 'CVC', 'PCP', 'XTO', 'ELV', 'PBG', 'ARII', 'CMCSK', 'DAL', 'BDX', 'RX', 'MJN', 'CCL', 'CMCSA', 'HIG', 'ADP', 'AAPL', 'AMD', 'CB', 'CB', 'COST', 'PLG', 'RTN', 'AAPL', 'VOD', 'PNX', 'KSS', 'HES', 'NRG', 'GOLD', 'STI', 'XL', 'LNY', 'BDX', 'GSK', 'LGF', 'WBA', 'LBTYA', 'FDX', 'CTXS', 'RTX', 'YUM', 'DTV', 'NKE', 'HIG', 'LH', 'STI', 'AWK', 'WTW', 'KR', 'ADSK', 'TGT', 'ELV', 'CVE', 'RF', 'RF', 'MJN', 'EBAY', 'CNQ', 'WTW', 'WBD', 'XRX', 'MVL', 'QRTEA', 'BKNG', 'PAS', 'ICON', 'CVC', 'WTM', 'CMCSK', 'PBI', 'STI', 'MI', 'CIT', 'ETFC']
2010-03-31 00:00:00: ['GE', 'GENZ', 'BIIB', 'DRYS', 'C', 'HPQ', 'MDLZ', 'XOM', 'CCI', 'MSFT', 'MDLZ', 'UPS', 'YUM', 'SDS', 'BAC', 'TRV', 'WFC', 'QCOM', 'JNJ', 'XOM', 'ANX', 'DTV', 'MRK', 'UPS', 'GGP', 'BAC', 'JPM', 'BAC', 'PFE', 'MSFT', 'MSI', 'QCOM', 'SLB', 'AMT', 'HPQ', 'KO', 'MRK', 'PG', 'MON', 'LGF', 'GS', 'CIE', 'BAC', 'PEP', 'PNC', 'GOLD', 'HD', 'ACN', 'ENZN', 'PFE', 'CXW', 'ACL', 'M', 'CVS', 'UPS', 'VVUS', 'ACL', 'MON', 'PNX', 'GLD', 'MMM', 'WBA', 'CMCSA', 'XRX', 'WFC', 'MON', 'UPS', 'MON', 'LOW', 'COV', 'MMM', 'SPLS', 'NKE', 'ODP', 'WFC', 'TGT', 'TFC', 'WU', 'MS', 'ACL', 'AMD', 'GLD', 'CVC', 'WBA', 'COST', 'GLRE', 'LO', 'SPY', 'STT', 'ACL', 'IVZ', 'ESRX', 'ELV', 'APOL', 'DTV', 'WPO', 'ATVI', 'CMCSK', 'BDX', 'V', 'ARII', 'PLG', 'ICON', 'RFMD', 'AXAS', 'GOLD', 'BDX', 'GSK', 'VLO', 'YUM', 'RTX', 'ADP', 'STI', 'ACL', 'COV', 'DTV', 'G', 'WTW', 'CMCSA', 'CMCSA', 'EMMS', 'AMZN', 'MJN', 'MS', 'BDX', 'COF', 'ETFC', 'DAL', 'ACL', 'AMT', 'CMCSK', 'AMP', 'EA', 'FBC', 'XTO', 'DAN', 'TM', 'ORLY', 'CCL', 'VLO', 'EXC', 'TNL', 'LYV', 'CNW', 'BKNG', 'TT', 'DEO', 'V', 'IWM', 'AMTD', 'LGF', 'SWN', 'LNCR', 'RSG', 'CTXS', 'CHKP', 'NUE', 'BRCD', 'ADSK', 'EXPE', 'XL', 'CIT', 'TSM', 'LNY', 'AAPL', 'CVE', 'SYA', 'NOK', 'SCHW', 'FXI', 'NRG', 'PVH', 'GRBK', 'MTB', 'RF', 'ICON', 'SBAC']
2010-06-30 00:00:00: ['GE', 'C', 'C', 'TRV', 'XOM', 'XRX', 'XRX', 'CCI', 'TRV', 'XOM', 'MSFT', 'MSI', 'JNJ', 'MSFT', 'GENZ', 'BAC', 'JNJ', 'BIIB', 'VIAB', 'AMT', 'HPQ', 'PFE', 'LO', 'C', 'QCOM', 'KO', 'GS', 'WMT', 'AMD', 'NBR', 'QCOM', 'TRV', 'GS', 'HD', 'NKE', 'UPS', 'RFMD', 'EMC', 'AXAS', 'GLD', 'HPQ', 'UPS', 'PG', 'ACL', 'XOM', 'YUM', 'MCD', 'JNJ', 'MRK', 'LEU', 'CMCSA', 'MS', 'EMMS', 'PXP', 'BP', 'CIE', 'ACN', 'ACL', 'PEP', 'EBAY', 'UPS', 'SLB', 'LOW', 'MJN', 'MMM', 'GOLD', 'NTR', 'CSCO', 'M', 'TGT', 'OVV', 'WBA', 'MSFT', 'MSI', 'DE', 'LBTYA', 'LMT', 'MRK', 'LWSN', 'BAX', 'TFC', 'G', 'MSI', 'COST', 'VXRT', 'AOL', 'MON', 'PEP', 'ORCL', 'INTC', 'ADP', 'CMCSA', 'BIDU', 'WFC', 'BAC', 'EA', 'MENT', 'VZ', 'PM', 'PFE', 'CMCSK', 'BAC', 'TWX', 'GILD', 'COF', 'BDX', 'DIS', 'ABT', 'COP', 'DUK', 'TTWO', 'WTW', 'GSK', 'LGF', 'JPM', 'GS', 'AMT', 'SLB', 'KO', 'QRTEA', 'TDW', 'WMT', 'PLG', 'ENZN', 'MCD', 'ATVI', 'WM', 'IBM', 'DG', 'OXY', 'DAL', 'CMCSK', 'EA', 'BNS', 'EBAY', 'SVU', 'AMGN', 'BA', 'DGX', 'COV', 'HD', 'APD', 'TT', 'VLO', 'ACL', 'QCOM', 'USB', 'RIG', 'SNV', 'DEO', 'RSG', 'UPS', 'AAPL', 'LLY', 'MDT', 'ACL', 'CNW', 'HSH', 'AMTD', 'TEVA', 'RTX', 'XRX', 'BAC', 'GRBK', 'EMC', 'LGND', 'HAIN', 'MHS', 'BAC', 'LH', 'GOLD', 'AMP', 'AON', 'TT', 'V', 'CVD', 'DIS', 'CNQ', 'DGX', 'MTB', 'HWM', 'F', 'TWX', 'MS', 'TDG', 'PFE', 'HPQ', 'UNH', 'CVE']
2010-09-30 00:00:00: ['GE', 'GE', 'C', 'C', 'TRV', 'GLD', 'XOM', 'XRX', 'CCI', 'C', 'XOM', 'CCI', 'TRV', 'C', 'JPM', 'GENZ', 'BAC', 'BIIB', 'MSFT', 'INTC', 'LMT', 'TRV', 'MCD', 'NTRS', 'QCOM', 'JNJ', 'JNJ', 'VLTC', 'UPS', 'XOM', 'CSCO', 'KO', 'QCOM', 'NKE', 'NBR', 'C', 'EMC', 'UPS', 'DCTH', 'AAPL', 'CFN', 'RBCN', 'LYV', 'JNJ', 'AXAS', 'MJN', 'EBAY', 'CVX', 'PEP', 'IBM', 'TXN', 'IBM', 'BK', 'UNH', 'LOW', 'CIE', 'MSFT', 'GS', 'ORCL', 'MSI', 'MDT', 'QRTEA', 'MSI', 'WFC', 'CSCO', 'EA', 'ESRX', 'BAX', 'COST', 'BAC', 'OVV', 'MRK', 'EA', 'PEP', 'G', 'ESRX', 'INTC', 'HD', 'LWSN', 'PM', 'RTX', 'EMMS', 'KKR', 'CMCSA', 'BKNG', 'ELV', 'ADP', 'COV', 'CIT', 'CIM', 'COP', 'VXRT', 'AMAT', 'BRCM', 'NTAP', 'NXPI', 'MENT', 'ABT', 'SPLS', 'TFC', 'ATVI', 'DE', 'GSK', 'BDX', 'BDX', 'MCD', 'APD', 'SCHW', 'CL', 'GS', 'APOL', 'KO', 'LGF', 'CSCO', 'OXY', 'WMT', 'TTWO', 'CMCSK', 'WM', 'HPQ', 'BKNG', 'DGX', 'TDW', 'TT', 'COF', 'AMAT', 'COV', 'AMZN', 'TDG', 'WTW', 'APOL', 'TWX', 'GOLD', 'AMGN', 'GS', 'HD', 'CTXS', 'ENZN', 'PLG', 'UPS', 'ADI', 'ALTR', 'MA', 'LH', 'EEM', 'GOLD', 'MDLZ', 'GRBK', 'CI', 'DFS', 'ACL', 'SU', 'K', 'EMC', 'MRK', 'DAL', 'RTX', 'F', 'TT', 'HIG', 'HSH', 'IVZ', 'MJN', 'DEO', 'ACL', 'GOOGL', 'AAPL', 'CNW', 'AMP', 'HWM', 'PWER', 'TRV', 'V', 'NTR', 'HAIN', 'CVS', 'LLTC', 'XLNX', 'CIT', 'CNQ', 'SGY', 'MHS']
2010-12-31 00:00:00: ['GE', 'GE', 'C', 'TRV', 'XOM', 'CCI', 'TRV', 'XRX', 'BIDU', 'TRV', 'CCI', 'XOM', 'GENZ', 'C', 'JPM', 'BIIB', 'CCI', 'WFC', 'JPM', 'JNJ', 'INTC', 'HPQ', 'MSFT', 'VLTC', 'QCOM', 'OVV', 'KO', 'MSFT', 'T', 'GM', 'XOM', 'CSCO', 'RBCN', 'GOLD', 'CIE', 'MRK', 'VZ', 'BAC', 'DCTH', 'QCOM', 'UPS', 'IBM', 'CSCO', 'GM', 'GM', 'EMC', 'RIO', 'GLD', 'GLD', 'NTR', 'JPM', 'ADP', 'MRO', 'EBAY', 'WFC', 'BK', 'NTR', 'MSFT', 'TXN', 'IBM', 'CVX', 'PG', 'JNJ', 'MDT', 'UNH', 'ESRX', 'MDT', 'EA', 'TGT', 'COST', 'G', 'TCOM', 'BAX', 'BB', 'DE', 'PLG', 'TRQ', 'LWSN', 'SHEL', 'GS', 'INTC', 'CIM', 'BRCM', 'TWX', 'OVV', 'MRK', 'LBTYK', 'PEP', 'K', 'TDG', 'PM', 'MENT', 'HPQ', 'MET', 'COP', 'HPQ', 'AIG', 'GOLD', 'MSFT', 'TFC', 'MHS', 'DTV', 'ACN', 'GSK', 'COF', 'TT', 'OVV', 'CMCSA', 'GS', 'MCD', 'TTWO', 'GLW', 'SPLS', 'WTW', 'OXY', 'CVE', 'EA', 'KO', 'TDW', 'CSCO', 'SVU', 'COV', 'UNP', 'V', 'PWER', 'BKNG', 'DEO', 'LGF', 'DAL', 'MJN', 'WM', 'MMM', 'SCHW', 'SU', 'CNW', 'CAT', 'ALTR', 'ADI', 'MHS', 'ENZN', 'PARA', 'CL', 'AMAT', 'XRX', 'LYB', 'HIG', 'SWK', 'DTV', 'HSH', 'F', 'GOLD', 'UPS', 'DFS', 'MDLZ', 'MO', 'USB', 'AMGN', 'EEM', 'DAL', 'EMC', 'MAT', 'LIFE', 'ACL', 'HWM', 'CIT', 'SVU', 'STI', 'NTAP', 'COST', 'BAX', 'CNQ', 'HUM', 'NTR', 'ICON', 'HAIN', 'GGP', 'MTB', 'MU', 'ROP', 'MDLZ', 'SWY', 'PFE', 'LYB']
2011-03-31 00:00:00: ['DRYS', 'GE', 'TRV', 'SPY', 'XRX', 'XOM', 'LVS', 'GENZ', 'BIDU', 'BIIB', 'T', 'USO', 'PARA', 'GLD', 'VLTC', 'ORCL', 'CLX', 'NTR', 'WFC', 'VZ', 'HSH', 'MSFT', 'MMI', 'MSFT', 'WFC', 'OVV', 'JPM', 'PEP', 'IBM', 'MRK', 'DIS', 'MGM', 'KO', 'BMY', 'PARA', 'LLY', 'LWSN', 'OXY', 'NTR', 'CIE', 'MENT', 'UPS', 'C', 'EBAY', 'EBAY', 'CSCO', 'UNH', 'STAR', 'STAR', 'MRO', 'GOLD', 'IBM', 'V', 'HD', 'TTWO', 'MDT', 'WFC', 'KO', 'STT', 'SHEL', 'AXAS', 'MET', 'CVS', 'MSFT', 'MET', 'GM', 'BK', 'HNZ', 'VZ', 'CVS', 'XRX', 'UNH', 'MET', 'CYBX', 'CFN', 'GLW', 'JPM', 'USB', 'TWX', 'G', 'EMC', 'LGF', 'COST', 'COV', 'ELV', 'C', 'LEAF', 'QCOM', 'GSK', 'BAX', 'UNP', 'BIDU', 'MSI', 'BDX', 'UNP', 'HAIN', 'MON', 'ENZN', 'MHS', 'RNR', 'TDG', 'LBTYK', 'MHS', 'BP', 'TXT', 'GLD', 'AON', 'LYB', 'ACN', 'BDX', 'STI', 'GDXJ', 'MSFT', 'KKR', 'HPQ', 'PLG', 'CL', 'YPF', 'TT', 'VLO', 'GD', 'GSK', 'FSLR', 'BP', 'BIG', 'SLB', 'TRV', 'HIG', 'WU', 'STJ', 'GOLD', 'EMMS', 'FITB', 'HCA', 'PNC', 'MRO', 'QCOM', 'AMAT', 'BKNG', 'SWY', 'CAH', 'DFS', 'VXRT', 'CMCSA', 'MHS', 'AMTD', 'QCOM', 'CFFN', 'MHS', 'STT', 'GRBK', 'COR', 'WY', 'DGX', 'DEO', 'AAPL', 'PWER', 'FIS', 'ROP', 'AMP', 'BAC', 'BLC', 'V', 'DAL', 'PDE', 'CBRE', 'LIFE', 'FDO', 'ODP', 'GOOGL', 'TXT', 'TFCF', 'CVE', 'LYV', 'ADSK', 'MTB', 'RL', 'PARA', 'CVC', 'SNY', 'KLAC', 'ASRT', 'STX', 'MJN', 'YOKU', 'DOX', 'WHR', 'FLIR', 'TEF', 'MA', 'HGG', 'MAS', 'MU', 'ST']
2011-06-30 00:00:00: ['GE', 'SPY', 'GLD', 'XRX', 'XOM', 'XOM', 'MSFT', 'ARCO', 'LLY', 'LVS', 'TWC', 'MSFT', 'LYB', 'VLTC', 'ORCL', 'JPM', 'MS', 'NTR', 'GLD', 'DTV', 'CVX', 'VOD', 'FRX', 'WFC', 'MDLZ', 'OSK', 'WFC', 'OVV', 'PEP', 'BP', 'GM', 'GM', 'WMT', 'CVS', 'MRK', 'EMR', 'MMI', 'MRO', 'VZ', 'MSFT', 'QCOM', 'MSFT', 'EBAY', 'CLX', 'HPQ', 'KO', 'GS', 'BAC', 'AMLN', 'BP', 'CMC', 'ORCL', 'CNX', 'BIDU', 'ARCO', 'JPM', 'GS', 'BDX', 'TRV', 'TRQ', 'TRV', 'MRO', 'WFC', 'UNH', 'NTR', 'WMB', 'GM', 'TTWO', 'PNC', 'EBAY', 'MENT', 'LYB', 'MDT', 'EMC', 'PM', 'USB', 'LOW', 'UPS', 'MET', 'CHTR', 'GOOGL', 'MET', 'CCI', 'C', 'HNZ', 'CMCSA', 'MHS', 'GOLD', 'CIE', 'HCA', 'INTC', 'LOW', 'RBCN', 'F', 'CIM', 'DGX', 'OXY', 'TDW', 'IBM', 'GOLD', 'FSLR', 'SNDK', 'AXAS', 'FDO', 'VOD', 'UNH', 'ACN', 'DUK', 'BAC', 'LGF', 'TEVA', 'DHR', 'ODP', 'MA', 'MHS', 'STAR', 'CLF', 'BK', 'STAR', 'HPQ', 'VGR', 'WY', 'HPQ', 'BBY', 'F', 'SHEL', 'COST', 'AGO', 'JEF', 'TFCF', 'HAIN', 'MDLZ', 'HHH', 'GOLD', 'CAT', 'EXPE', 'CVS', 'SU', 'PFE', 'BKNG', 'XRX', 'MET', 'ESRX', 'HD', 'MHS', 'S', 'MO', 'AMP', 'ENZN', 'JEF', 'STI', 'G', 'AMT', 'HIG', 'ADSK', 'HD', 'GLW', 'AON', 'CL', 'QRTEA', 'DOX', 'GOLD', 'TDG', 'FITB', 'NWL', 'USB', 'EBAY', 'RNR', 'ARII', 'AGO', 'HAL', 'BDX', 'HD', 'MHS', 'GLD', 'EEM', 'BDX', 'T']
2011-09-30 00:00:00: ['GE', 'WFC', 'T', 'VZ', 'SPY', 'ARCO', 'XOM', 'XOM', 'PFE', 'PEP', 'MSFT', 'GLD', 'JPM', 'GS', 'MSFT', 'C', 'BP', 'LOW', 'CVX', 'ORCL', 'GOLD', 'EBAY', 'ONCT', 'ADBE', 'NOG', 'WFC', 'LYB', 'GS', 'CVX', 'PARA', 'VZ', 'HNZ', 'CVS', 'CVS', 'MSFT', 'VOD', 'INTC', 'SHEL', 'USB', 'KO', 'CLX', 'QCOM', 'NAV', 'OVV', 'ARCO', 'FRX', 'MSFT', 'CCI', 'MS', 'GOOGL', 'C', 'C', 'WBMD', 'IBM', 'XLE', 'TRV', 'AAPL', 'TRV', 'EBAY', 'MRO', 'PNC', 'PM', 'CCI', 'WFC', 'GOLD', 'NTR', 'OSK', 'SINA', 'JPM', 'LYB', 'ESRX', 'RTX', 'AMLN', 'GM', 'MOS', 'CHTR', 'YUM', 'GOLD', 'TRQ', 'UPS', 'GOLD', 'STT', 'GILD', 'QRTEA', 'CVS', 'TTWO', 'CMC', 'DUK', 'LQD', 'AXAS', 'CMLS', 'MENT', 'OVV', 'BDX', 'C', 'EMC', 'BAC', 'PARA', 'TDW', 'VLTC', 'VOD', 'PPO', 'COST', 'RNR', 'GDXJ', 'TEVA', 'G', 'NTAP', 'GLW', 'SHEL', 'OXY', 'PEP', 'DTV', 'CMCSA', 'MO', 'CE', 'LOW', 'UNH', 'A', 'VGR', 'HCA', 'STAR', 'ESRX', 'CL', 'QCOM', 'CVS', 'BK', 'DAL', 'GOLD', 'HAIN', 'EGO', 'S', 'EXPE', 'WMT', 'FSLR', 'XRX', 'SU', 'HHH', 'LOW', 'MOS', 'CVC', 'EBAY', 'AGCO', 'AMP', 'CP', 'GD', 'BAX', 'FDO', 'AON', 'GOOGL', 'SONY', 'ODP', 'BIDU', 'TIN', 'GG', 'SNDK']
2012-12-31 00:00:00: ['GE', 'WFC', 'PG', 'RIG', 'C', 'GLD', 'JPM', 'MDLZ', 'QCOM', 'HNZ', 'CCI', 'UPS', 'ABT', 'JNJ', 'BAC', 'MRK', 'TFCF', 'PEP', 'CMG', 'STT', 'OVV', 'SPY', 'COF', 'EBAY', 'COF', 'ARCO', 'C', 'GOLD', 'OCN', 'CVS', 'FRAN', 'MSFT', 'MENT', 'VOD', 'PFE', 'LOW', 'NAV', 'WFC', 'WFC', 'ORCL', 'HPQ', 'MSI', 'TIF', 'NTR', 'FIS', 'LVS', 'FCX', 'FRX', 'TTWO', 'IP', 'MWV', 'HAIN', 'SPGI', 'MCO', 'SPY', 'PEP', 'PEP', 'DRYS', 'SIRI', 'FCX', 'DIS', 'XRX', 'UPS', 'CIM', 'WBMD', 'WDC', 'CMG', 'TWO', 'S', 'P', 'OCN', 'BP', 'GOOGL', 'TDG', 'AIG', 'CIT', 'GOLD', 'VRSN', 'AAPL', 'AAPL', 'MDLZ', 'QQQ', 'DG', 'JPM', 'CHTR', 'HIG', 'AGU', 'ARII', 'COST', 'LLY', 'COP', 'TRQ', 'LIFE', 'TWO', 'GM', 'NFLX', 'PVH', 'FDML', 'VLO', 'JEF', 'DE', 'ATVI', 'AXP', 'CVH']
2013-09-30 00:00:00: ['GE', 'PG', 'WFC', 'C', 'DIS', 'TLM', 'GILD', 'JPM', 'DD', 'VOD', 'INTC', 'JPM', 'RIG', 'BAC', 'MRK', 'DRYS', 'OCN', 'JNJ', 'QCOM', 'LBTYA', 'SPY', 'AXP', 'C', 'CVRR', 'TIF', 'FRX', 'UPS', 'CMCSA', 'OCN', 'NUAN', 'MON', 'LOW', 'NAV', 'MENT', 'HIG', 'APTV', 'ATVI', 'CHTR', 'V', 'BEL', 'GRPN', 'VOYA', 'TTWO', 'EMC', 'LNC', 'DOX', 'CTRA', 'LBTYK', 'NLSN', 'COF', 'UPS', 'TRIP', 'FCX', 'OCSL', 'NVR', 'TWO', 'GGP', 'QRTEA', 'COP', 'HES', 'HLF', 'TFCF', 'MDLZ', 'F', 'AIG', 'LM', 'LAZ', 'URS', 'RCL', 'META', 'CME', 'STNG', 'DXC', 'CCL', 'WPX', 'SU', 'GNW', 'COST', 'PSX', 'CIM', 'TMO', 'FCX', 'WMB', 'AMT', 'GDX', 'SPR', 'CIM', 'FDO', 'BWXT', 'NOK', 'TMUS', 'V', 'XLF', 'KRFT', 'SNDK', 'EQT', 'LM', 'APTV', 'ARII', 'DXJ', 'PCP', 'PGEN', 'PRU', 'DE', 'GRA', 'DDD', 'MPC', 'QCOM', 'AHL']
2013-12-31 00:00:00: ['PG', 'GE', 'WFC', 'C', 'GE', 'MSFT', 'JPM', 'DD', 'GRPN', 'RIG', 'EMC', 'SPY', 'BP', 'DD', 'VOD', 'TLM', 'C', 'JPM', 'JNJ', 'VZ', 'CIE', 'GM', 'DIS', 'TWTR', 'QCOM', 'APC', 'AGN', 'FRX', 'SLB', 'TIF', 'HOLX', 'DD', 'META', 'MSFT', 'QCOM', 'AXP', 'V', 'TWER', 'MSFT', 'CVRR', 'LBTYA', 'MET', 'ESRX', 'GILD', 'C', 'AGN', 'WFC', 'NUAN', 'HIG', 'EBAY', 'NAV', 'CMCSA', 'DD', 'MENT', 'GM', 'LNC', 'LOW', 'CMCSA', 'APTV', 'GPS', 'CHTR', 'NFLX', 'VNCE', 'HLF', 'BIDU', 'CMCSA', 'XRX', 'UPS', 'COF', 'YNDX', 'EMC', 'ORCL', 'AIG', 'NETI', 'CMCSA', 'MRK', 'COP', 'HAL', 'MRK', 'BIDU', 'FCX', 'F', 'LAZ', 'TWO', 'PARA', 'MDLZ', 'WMB', 'CSCO', 'RCL', 'LBTYK', 'META', 'OMC', 'ALLE', 'GNW', 'LM', 'VOYA', 'DDD', 'AXP', 'DOX', 'PEP', 'AAPL', 'MET', 'ABT', 'AON', 'HES', 'STNG', 'TT', 'FDO', 'SU', 'MNDT', 'COST', 'GRA', 'BMY', 'CME', 'SSYS', 'RMD']
2014-03-31 00:00:00: ['PALI', 'GE', 'WFC', 'AGN', 'WINT', 'C', 'AGN', 'T', 'MSFT', 'EBAY', 'MSFT', 'DD', 'JPM', 'BK', 'BP', 'JNJ', 'RIG', 'META', 'QCOM', 'C', 'TWTR', 'CIE', 'SLB', 'META', 'OCN', 'NOV', 'QCOM', 'V', 'TLM', 'OCN', 'DIS', 'AIG', 'VOD', 'EMC', 'VZ', 'TIF', 'CMCSA', 'LO', 'MDLZ', 'AAPL', 'ESRX', 'WBA', 'HME', 'BHC', 'AIG', 'MON', 'LBTYK', 'HOLX', 'CMCSA', 'VOD', 'BIDU', 'UNH', 'HRI', 'DD', 'GPS', 'CMCSA', 'TWC', 'JPM', 'MET', 'HIG', 'HHH', 'VNCE', 'CVRR', 'AGN', 'APC', 'MWE', 'BIDU', 'MSI', 'COF', 'F', 'LBTYA', 'MNDT', 'MA', 'APC', 'LNC', 'NOV', 'NUAN', 'LRCX', 'UPS', 'PRU', 'COP', 'TWO', 'NAV', 'ALLE', 'MENT', 'MDLZ', 'NOK', 'GM', 'C', 'BKNG', 'PARA', 'NFLX', 'LAZ', 'S', 'HES', 'AGN', 'GNW', 'RMD', 'SCTY', 'HLF', 'MA', 'CMCSK', 'SU', 'STNG', 'DOX', 'AGNC', 'COST', 'DDD', 'OCSL', 'PSX', 'AMT', 'CDNS', 'FDO', 'TWC', 'GM', 'OMC', 'KATE', 'AAL', 'VOYA', 'TT', 'PSX', 'KRFT', 'VZ', 'CHTR', 'APTV', 'TT', 'PCP']
2014-06-30 00:00:00: ['GE', 'WFC', 'MSFT', 'C', 'T', 'EBAY', 'BIOL', 'DD', 'AMGN', 'MO', 'WBA', 'INTC', 'BP', 'JNJ', 'APC', 'SLB', 'APD', 'PARA', 'BKW', 'EMC', 'RIG', 'BKNG', 'HHH', 'TWTR', 'WBA', 'NBR', 'C', 'FRTX', 'VEON', 'TIF', 'NOV', 'V', 'DIS', 'VZ', 'CVEO', 'JNJ', 'TLM', 'AIG', 'ONTX', 'BK', 'DD', 'FDX', 'VOD', 'AAL', 'LBTYK', 'VNCE', 'TGNA', 'CCI', 'CMCSA', 'MCK', 'BIDU', 'CMCSA', 'ESI', 'TWER', 'APC', 'COP', 'KO', 'HOLX', 'BIDU', 'GM', 'VOD', 'MRK', 'AAPL', 'ONCT', 'RIG', 'NRF', 'WMB', 'EQT', 'RAI', 'HIG', 'CP', 'SPY', 'PRU', 'S', 'C', 'MA', 'AET', 'UPS', 'ACHV', 'F', 'ALLE', 'MET', 'MET', 'PSX', 'LNC', 'HRI', 'EBAY', 'LBTYA', 'WBA', 'LBTYK', 'CVRR', 'MDLZ', 'NUAN', 'AON', 'AAL', 'LAZ', 'HD', 'AER', 'AVGO', 'STNG', 'UNH', 'UNH', 'PEP', 'MNDT', 'WMB', 'NFLX', 'KING', 'KKR', 'GRUB', 'CI', 'SU', 'RMD', 'LNG', 'LRCX', 'TT', 'VOYA', 'AGNC', 'NAV', 'FIS', 'ABBV', 'DOX', 'OXY', 'FDO', 'COST', 'LBTYK', 'GNW', 'BA', 'DXC', 'NXPI', 'MENT', 'COF', 'COF', 'BRCM', 'GPS', 'LNG', 'PSX', 'HLF', 'GM', 'NOV', 'NOV', 'LLY', 'HRI', 'CI', 'KRFT']
2014-09-30 00:00:00: ['GE', 'WFC', 'GE', 'C', 'BKNG', 'DD', 'ZTS', 'DIS', 'EBAY', 'INTC', 'TWTR', 'SLB', 'JNJ', 'AMGN', 'APC', 'V', 'BP', 'EMC', 'C', 'AAPL', 'BP', 'PARA', 'UNH', 'BKW', 'APD', 'MSFT', 'DD', 'TIF', 'WMB', 'VZ', 'FDX', 'RIG', 'KO', 'DD', 'SPY', 'HHH', 'HRI', 'SYF', 'MET', 'NOV', 'C', 'TWER', 'TWX', 'ABBV', 'TLM', 'EBAY', 'CMCSA', 'XOM', 'JNJ', 'APC', 'VOD', 'META', 'PEP', 'LBTYK', 'MSFT', 'GRPN', 'PG', 'HIG', 'VOD', 'TGNA', 'VZ', 'AAL', 'CVX', 'MR', 'QCOM', 'F', 'COP', 'CVEO', 'HOLX', 'LNC', 'CI', 'ORCL', 'PSX', 'DBRG', 'LNG', 'MRK', 'TT', 'ESI', 'GM', 'J', 'AAPL', 'MA', 'HD', 'AET', 'LAZ', 'EQT', 'AVGO', 'IBM', 'UPS', 'RMD', 'BABA', 'WMT', 'AXP', 'PEP', 'TRP', 'APC', 'XOM', 'TAP', 'MA', 'S', 'KMI', 'LBTYA', 'PM', 'ALLE', 'KKR', 'TWO', 'FLT', 'IWM', 'MDLZ', 'CHL', 'CVRR', 'MNDT', 'NUAN', 'NFLX', 'PH', 'FDO', 'IPG', 'ESRX', 'LBTYK', 'AER', 'CMCSA', 'BRCM', 'BABA', 'EBAY', 'CFG', 'BLK', 'PE', 'ABBV', 'COST']
2014-12-31 00:00:00: ['GE', 'WFC', 'EVFM', 'SPY', 'C', 'MSFT', 'SPY', 'CCI', 'LC', 'EBAY', 'INTC', 'ZTS', 'JNJ', 'COV', 'EIGR', 'V', 'VER', 'AAPL', 'SPY', 'JPM', 'TWER', 'C', 'APD', 'MSFT', 'AAPL', 'EMC', 'KO', 'WBA', 'CNQ', 'TWTR', 'C', 'AET', 'XOM', 'TIF', 'AGN', 'VZ', 'LBTYK', 'CVX', 'META', 'AGN', 'AIG', 'TWX', 'JNJ', 'GILD', 'PG', 'HD', 'DD', 'KO', 'MET', 'QSR', 'HRI', 'KMI', 'WBA', 'ORCL', 'ONVO', 'HHH', 'J', 'VZ', 'TLM', 'BK', 'VOD', 'EMC', 'LC', 'DBRG', 'APC', 'TGNA', 'LO', 'RIG', 'AAPL', 'PSX', 'TT', 'AGN', 'HOLX', 'VER', 'MRK', 'MA', 'LBTYA', 'IBM', 'AGN', 'AGN', 'UPS', 'ESI', 'DAL', 'PEP', 'JD', 'AGN', 'PM', 'LAZ', 'AAL', 'WMB', 'EMN', 'CHL', 'PPC', 'ALLE', 'MDLZ', 'FDO', 'CVS', 'CP', 'ABBV', 'BHC', 'TWC', 'BMY', 'AXP', 'TWO', 'GM', 'MO', 'VTLE', 'BKR', 'LRCX', 'COST', 'CCI', 'CELG', 'TRP', 'QSR', 'AMAT', 'ODP', 'NUAN', 'GS', 'DOX', 'GRUB', 'AIG']
2015-03-31 00:00:00: ['WFC', 'EVFM', 'GE', 'AGN', 'AGN', 'IBM', 'SPY', 'BAC', 'V', 'EBAY', 'BK', 'EIGR', 'JNJ', 'CNQ', 'EMC', 'SLRX', 'TWER', 'XOM', 'EIGR', 'JPM', 'LC', 'EBAY', 'JNJ', 'IBM', 'META', 'AIG', 'SPY', 'TWTR', 'VZ', 'PG', 'HD', 'MCK', 'GM', 'TIF', 'T', 'ABBV', 'TT', 'LBTYK', 'UVXY', 'FDX', 'YUM', 'MRK', 'FDO', 'TCRT', 'IBM', 'INTC', 'KO', 'M', 'MET', 'TWX', 'TGNA', 'HRI', 'V', 'PEP', 'HOLX', 'DBRG', 'V', 'BK', 'PSX', 'PCP', 'PM', 'VOD', 'C', 'CVS', 'MA', 'DAL', 'MU', 'LO', 'GM', 'MO', 'LBTYA', 'LOW', 'RTX', 'ABBV', 'RIG', 'PSX', 'QQQ', 'YUM', 'ALLE', 'NXPI', 'UPS', 'WBA', 'ESRX', 'ET', 'TWC', 'TWX', 'BKR', 'KO', 'MDLZ', 'GM', 'VER', 'LBTYK', 'IWM', 'ABT', 'TWO', 'GRPN', 'TRP', 'LRCX', 'COST', 'WBA', 'GM', 'ODP', 'KRFT', 'ABT', 'MCD', 'RTX', 'HHH', 'MHK', 'SC', 'BUD', 'APC', 'MCD', 'NUAN', 'LBTYK']
2015-06-30 00:00:00: ['CYTO', 'PALI', 'GE', 'EVFM', 'PSTV', 'GE', 'IBM', 'SPY', 'V', 'BAC', 'EBAY', 'NOV', 'ZTS', 'BABA', 'JNJ', 'LNG', 'GILD', 'BK', 'LC', 'EBAY', 'AIG', 'TFCF', 'VZ', 'HHH', 'YUM', 'LBTYK', 'M', 'WMB', 'QSR', 'AIG', 'JNJ', 'TWX', 'FDX', 'AMAT', 'ESI', 'TMUS', 'ABBV', 'HOLX', 'V', 'C', 'PFE', 'CHTR', 'APD', 'VOD', 'XOM', 'JEF', 'DAL', 'PG', 'TGNA', 'MA', 'HRI', 'DBRG', 'EBAY', 'LBTYA', 'TCRT', 'MRK', 'INTC', 'IBM', 'PRGO', 'DHR', 'RIG', 'GM', 'BHC', 'PSX', 'BPTH', 'BK', 'PEP', 'CHTR', 'UVXY', 'MCD', 'UPS', 'V', 'PM', 'MDLZ', 'PSX', 'BABA', 'LRCX', 'CVS', 'CMCSA', 'TEVA', 'ABBV', 'SC', 'BMY', 'RF', 'VER', 'TMUS', 'MCK', 'LBTYK', 'MO', 'MHK', 'TRIP', 'NXPI', 'UAL', 'NUAN', 'KRFT', 'MNDT', 'COST', 'MMM', 'CP', 'LBTYK', 'GE', 'LLY', 'DVN', 'AVGO', 'SPLK', 'HRI', 'MCD', 'AET', 'WBA', 'YUM', 'GCI', 'HOT', 'BAX', 'BABA', 'SPR']
2015-09-30 00:00:00: ['GE', 'EVFM', 'IBM', 'GE', 'SPY', 'AAPL', 'AIG', 'IBM', 'AIG', 'MDLZ', 'AAPL', 'C', 'MA', 'C', 'TWC', 'PYPL', 'JNJ', 'BABA', 'VEON', 'LC', 'JPM', 'MSFT', 'BK', 'DHR', 'YUM', 'TWC', 'SPY', 'NKE', 'TMUS', 'AIG', 'VZ', 'TWX', 'CHTR', 'PEP', 'ZTS', 'KMI', 'LBTYK', 'TFCF', 'AVGO', 'JNJ', 'HD', 'V', 'BAC', 'TWER', 'AMGN', 'AMAT', 'PFE', 'EBAY', 'ALL', 'FCX', 'BMY', 'TMUS', 'UAL', 'XOM', 'GM', 'HOLX', 'MSFT', 'HHH', 'MA', 'ABBV', 'CMCSA', 'PG', 'LBTYK', 'NXPI', 'BK', 'VOD', 'LNG', 'NOV', 'TGNA', 'WBA', 'INTC', 'MCD', 'HLT', 'QSR', 'STZ', 'T', 'TMUS', 'HRI', 'LUV', 'UPS', 'PEP', 'MRK', 'LYB', 'LBTYA', 'PM', 'MDLZ', 'V', 'EBAY', 'MU', 'CMG', 'BHC', 'BKNG', 'CI', 'TT', 'MO', 'CVS', 'LOW', 'TAP', 'RIG', 'PEP', 'BUD', 'SJM', 'BUD', 'COST', 'TWO', 'DAL', 'APC', 'SPLK', 'BMY', 'CMG', 'BUD', 'ESI', 'ROP', 'WBA', 'AER']
2015-12-31 00:00:00: ['GE', 'MSFT', 'IBM', 'GE', 'UVXY', 'MSFT', 'SPY', 'MSFT', 'AIG', 'AGN', 'KHC', 'XRX', 'PFE', 'VEON', 'BABA', 'AGN', 'EMC', 'WFC', 'MS', 'JNJ', 'AIG', 'PFE', 'PYPL', 'MSFT', 'MA', 'CI', 'DHR', 'SPY', 'BK', 'TWC', 'YUM', 'TWC', 'PM', 'CB', 'VZ', 'AVGO', 'HUM', 'EBAY', 'TWC', 'BAX', 'AMGN', 'AAPL', 'JPM', 'JNJ', 'BKNG', 'BHC', 'CVS', 'V', 'VER', 'TWX', 'CB', 'CNQ', 'HHH', 'WBA', 'AVGO', 'AIG', 'SNDK', 'PFE', 'TRP', 'LC', 'PG', 'LBTYK', 'AMT', 'BHC', 'LBTYK', 'MA', 'BKNG', 'TFCF', 'HOLX', 'STZ', 'LBTYK', 'INTC', 'T', 'VOD', 'XOM', 'AMLP', 'HLT', 'SCHW', 'CVX', 'ODP', 'FCX', 'PM', 'AET', 'CHTR', 'PEP', 'MRK', 'AAPL', 'V', 'MDLZ', 'LNG', 'IBM', 'TAP', 'UPS', 'TGNA', 'CHTR', 'AMAT', 'AAL', 'LBTYA', 'NXPI', 'MO', 'ROP', 'UAL', 'ESI', 'BMY', 'BUD', 'CVS', 'QSR', 'HRI', 'PEP', 'SJM', 'COST', 'PPG', 'MDT']
2016-03-31 00:00:00: ['GE', 'UVXY', 'MSFT', 'MA', 'VEON', 'SPY', 'AGN', 'XRX', 'KHC', 'MDLZ', 'MSFT', 'EMC', 'JNJ', 'PFE', 'AAPL', 'PG', 'PG', 'CI', 'BK', 'XOM', 'JNJ', 'META', 'BAC', 'PYPL', 'AGN', 'JEF', 'VZ', 'AAPL', 'LC', 'LOW', 'HUM', 'AVGO', 'BHC', 'LOW', 'VER', 'PG', 'SPY', 'BAX', 'EMC', 'CVX', 'GILD', 'BKNG', 'MCK', 'PFE', 'TWC', 'PM', 'FCX', 'INTC', 'TWC', 'CVS', 'MDT', 'YUM', 'V', 'ODP', 'CHTR', 'PEP', 'MRK', 'AAPL', 'GILD', 'WFC', 'IBM', 'LBTYK', 'AAPL', 'TFCF', 'CB', 'V', 'FIS', 'HHH', 'SBUX', 'WBA', 'MO', 'TFCF', 'NKE', 'LBTYK', 'MA', 'CVS', 'DD', 'CI', 'AGN', 'VOD', 'CTSH', 'BMY', 'GM', 'MCD', 'CHTR', 'QSR', 'NWS', 'TEVA', 'MDT', 'NUAN', 'UPS', 'SLB', 'RIG', 'KHC', 'LNG', 'DHR', 'CL', 'ABBV', 'HRI', 'WBA', 'HUM', 'UNP', 'AAL', 'LOW', 'LBTYA', 'MDLZ', 'BXLT', 'KMI', 'AAP', 'CFG', 'TRP']
2016-06-30 00:00:00: ['UVXY', 'GE', 'AAPL', 'SPY', 'MA', 'MSFT', 'AGN', 'VEON', 'PG', 'JNJ', 'CI', 'SPY', 'DIS', 'NBR', 'META', 'ESRX', 'AGN', 'XOM', 'JNJ', 'PG', 'HRI', 'DD', 'HUM', 'BAC', 'KMI', 'JEF', 'UNP', 'XRX', 'GM', 'TMUS', 'DD', 'VZ', 'CVS', 'PG', 'CVX', 'VER', 'AGN', 'COR', 'LOW', 'CHTR', 'WBA', 'PPG', 'GD', 'NWS', 'MON', 'BHC', 'LBTYK', 'TEVA', 'BKNG', 'TFCF', 'BCE', 'VOD', 'C', 'AMLP', 'PM', 'INTC', 'MRK', 'EMC', 'WFC', 'PRGO', 'PEP', 'V', 'CMCSA', 'EPD', 'AGN', 'LOW', 'LOW', 'MO', 'FIS', 'NWS', 'LC', 'GD', 'AAPL', 'CHTR', 'BMY', 'HHH', 'QSR', 'TWX', 'MDT', 'SLB', 'CI', 'CI', 'MA', 'ABBV', 'MON', 'CVS', 'KHC', 'MMM', 'KHC', 'MCD', 'ATVI', 'TT', 'MDLZ', 'ABT', 'UPS', 'AAPL', 'AGR', 'LBTYA', 'MON']
2016-09-30 00:00:00: ['UVXY', 'GE', 'AGN', 'V', 'MSFT', 'BAC', 'CMG', 'SPY', 'ZTS', 'AAPL', 'VEON', 'C', 'JNJ', 'CI', 'MA', 'BKNG', 'V', 'NBR', 'PG', 'META', 'PG', 'BAC', 'CMCSA', 'JNJ', 'EMC', 'EMC', 'KO', 'CMG', 'XOM', 'TWX', 'JEF', 'UNP', 'PEP', 'VZ', 'LBTYK', 'PM', 'ESRX', 'AAPL', 'PG', 'QCOM', 'VEON', 'VEON', 'DD', 'X', 'AAPL', 'XRX', 'PFE', 'CVX', 'SPY', 'WFC', 'AMGN', 'SPY', 'CHTR', 'GM', 'INTC', 'MRK', 'BCE', 'V', 'BKNG', 'AAPL', 'VER', 'BABA', 'PEP', 'TEVA', 'NXPI', 'EMC', 'MA', 'CI', 'YUM', 'AGR', 'NXPI', 'MO', 'WBA', 'LBTYA', 'EPD', 'PVH', 'TWX', 'BKNG', 'PM', 'SLB', 'CB', 'MDT', 'CHTR', 'UPS', 'ABBV', 'KHC', 'BIIB', 'MMM', 'PNC', 'HPE', 'AAPL', 'CL', 'AMLP', 'GD', 'CVS', 'WTW', 'CHTR', 'DAL', 'MDLZ', 'CCEP']
2017-03-31 00:00:00: ['WPG', 'GE', 'JEF', 'GE', 'MSFT', 'APD', 'META', 'XRX', 'NBR', 'MON', 'MSFT', 'PYPL', 'TWX', 'JNJ', 'MSFT', 'AAPL', 'V', 'CI', 'MSFT', 'INTC', 'MU', 'VEON', 'PG', 'UNH', 'MDLZ', 'V', 'VZ', 'DD', 'MA', 'BMY', 'CMCSA', 'FCX', 'CHTR', 'PFE', 'BKNG', 'JNJ', 'JPM', 'CVX', 'BKNG', 'AAPL', 'PFE', 'CHTR', 'JEF', 'CMCSA', 'V', 'TMUS', 'LBTYK', 'V', 'DIS', 'HON', 'NFLX', 'MON', 'GE', 'KMI', 'TWX', 'CSCO', 'XOM', 'CMCSA', 'MT', 'IBM', 'V', 'LOW', 'AA', 'OVV', 'PG', 'SPY', 'MA', 'WFC', 'NFLX', 'TMO', 'PM', 'RIO', 'AMT', 'CVX', 'QCOM', 'VZ', 'DD', 'LLY', 'PFE', 'AMLP', 'SPY', 'C', 'ORCL', 'HCA', 'T', 'AMGN', 'EBAY', 'AAPL', 'MA', 'DD', 'HHH', 'MTW', 'INTC', 'TMUS', 'MRK', 'MCD', 'BKNG', 'UPS', 'CNDT', 'WMT', 'BAC', 'IBM', 'HON', 'JPM', 'VER', 'AGN', 'LLY', 'MDLZ', 'MO', 'LBTYA']
2017-06-30 00:00:00: ['WPG', 'JEF', 'PYPL', 'ADP', 'META', 'JNJ', 'MSFT', 'MON', 'WFC', 'MDLZ', 'PG', 'MSFT', 'V', 'VZ', 'META', 'MU', 'AABA', 'UNH', 'V', 'CCI', 'SPY', 'MA', 'NKE', 'AAPL', 'UNH', 'JNJ', 'MA', 'AAPL', 'VZ', 'HON', 'NBR', 'GE', 'HPE', 'VEON', 'MSFT', 'CMCSA', 'ABBV', 'V', 'BKNG', 'FCX', 'CHTR', 'LOW', 'CMCSA', 'XOM', 'WBA', 'QCOM', 'NYRT', 'BAC', 'MON', 'JEF', 'NFLX', 'NFLX', 'WFC', 'AA', 'SPY', 'PG', 'DD', 'MMM', 'UPS', 'WMT', 'AGN', 'JPM', 'KMI', 'XRX', 'CVX', 'AMT', 'RIO', 'PFE', 'MDLZ', 'AAPL', 'VZ', 'COST', 'DD', 'T', 'CRM', 'MRK', 'CHTR', 'GS', 'TMO', 'INTC', 'MTW', 'MON', 'BIIB', 'GD', 'CSCO', 'PVH', 'MA', 'MO', 'ELV', 'NKE', 'ACN', 'WMT', 'IBM', 'CHTR', 'CNDT', 'ATVI', 'MON', 'BABA', 'VER', 'ADBE', 'SYK', 'ELV', 'GM', 'ABBV', 'PRGO', 'WBT', 'MDT', 'MCD', 'PEP', 'HUM', 'DAL']
2018-12-31 00:00:00: ['JEF', 'GE', 'AIU', 'BAC', 'SD', 'WFC', 'MSFT', 'FCX', 'DD', 'MSFT', 'JNJ', 'MSFT', 'JEF', 'XELA', 'TRV', 'V', 'FANG', 'VZ', 'PG', 'V', 'VSTO', 'UNH', 'V', 'MA', 'NWL', 'MA', 'SPY', 'ADP', 'MRK', 'TRV', 'UNH', 'VTAK', 'CRM', 'CRM', 'JNJ', 'XRX', 'LNG', 'META', 'CI', 'BABA', 'RTX', 'XOM', 'MDLZ', 'SPY', 'DD', 'MA', 'ADBE', 'SPY', 'UNH', 'JPM', 'PFE', 'PG', 'CI', 'CVS', 'BK', 'CVX', 'WFC', 'COST', 'MRK', 'CNDT', 'LOW', 'NAV', 'ADBE', 'WBA', 'UPS', 'PYPL', 'CSCO', 'SPGI', 'AGN', 'V', 'MDLZ', 'CVRR', 'ABBV', 'WBT', 'SHY', 'TEN', 'V', 'UXIN', 'C', 'WFC', 'ABT', 'PPG', 'AMZN', 'CRM', 'FDX', 'C', 'PEP', 'PNC', 'CHTR', 'MCD', 'HUM', 'VER']
2019-09-30 00:00:00: ['XELA', 'KHC', 'GE', 'MSFT', 'AIU', 'BA', 'MSFT', 'OXY', 'UNH', 'JNJ', 'PG', 'V', 'TRV', 'FCX', 'HPQ', 'META', 'A', 'MA', 'V', 'MA', 'SD', 'ADBE', 'CRM', 'MSFT', 'META', 'TRV', 'WFC', 'V', 'ADBE', 'AVGO', 'TMO', 'UNH', 'BA', 'LNG', 'JNJ', 'FIS', 'LOW', 'PG', 'XOM', 'AGN', 'MDLZ', 'MA', 'NWL', 'TMO', 'TMUS', 'BK', 'ADBE', 'SBUX', 'XRX', 'COST', 'AAPL', 'META', 'ABBV', 'V', 'MRK', 'UNH', 'TMUS', 'CRM', 'JPM', 'UPS', 'PFE', 'V', 'MDLZ', 'CVS', 'CSCO', 'BKNG', 'HUM', 'AMLP', 'HHH', 'UNH', 'CHTR', 'ABT', 'PEP', 'CZR', 'KO', 'MCD', 'MDT', 'UNP', 'WBT', 'NAV', 'GPN', 'UBER', 'UBER', 'PNC', 'ACN', 'HON', 'NKE', 'BLK', 'AXP', 'ET', 'WMT']
2019-12-31 00:00:00: ['XELA', 'GE', 'VSTO', 'MSFT', 'AIU', 'SBUX', 'OXY', 'UNH', 'META', 'FCX', 'JNJ', 'MSFT', 'V', 'ADBE', 'PG', 'SPY', 'TRV', 'A', 'CRM', 'MA', 'META', 'HPQ', 'V', 'MA', 'AVGO', 'META', 'SD', 'WFC', 'ADBE', 'V', 'JNJ', 'MA', 'TRV', 'SCHW', 'ADBE', 'LNG', 'PG', 'TMUS', 'AAPL', 'SPY', 'CRM', 'XOM', 'NWL', 'UNP', 'UNH', 'VOO', 'RTN', 'XRX', 'HUM', 'MSFT', 'BK', 'COST', 'MDLZ', 'BABA', 'MRK', 'CVS', 'PFE', 'PYPL', 'TMO', 'AMZN', 'RACE', 'V', 'V', 'MO', 'AMLP', 'CSCO', 'BA', 'JPM', 'BA', 'UPS', 'SPGI', 'PYPL', 'MDLZ', 'CHTR', 'KO', 'ABT', 'FIS', 'PEP', 'BSX', 'MDT', 'ACN', 'ABBV', 'CLDR', 'MCD', 'NAV', 'NFLX', 'NKE', 'HHH', 'PNC', 'BLK', 'WBT', 'GS', 'HON', 'SHY', 'TXN']
2020-03-31 00:00:00: ['GE', 'XELA', 'MSFT', 'SPG', 'MSFT', 'META', 'AIU', 'KHC', 'BX', 'OXY', 'MA', 'HPQ', 'JNJ', 'FCX', 'PG', 'V', 'SPY', 'V', 'JPM', 'DIS', 'MA', 'DIS', 'LNG', 'ABT', 'META', 'MA', 'MDT', 'META', 'OXY', 'AMT', 'UNH', 'NWL', 'JNJ', 'UNH', 'ADBE', 'VOO', 'MSFT', 'XRX', 'PG', 'AAPL', 'MDLZ', 'CHTR', 'META', 'WFC', 'COST', 'JPM', 'AGN', 'CZR', 'D', 'SBUX', 'SPY', 'UNH', 'V', 'V', 'LOW', 'CRM', 'BKNG', 'BK', 'WES', 'GS', 'MRK', 'CME', 'MA', 'RTN', 'PYPL', 'ADBE', 'PFE', 'ADBE', 'MDLZ', 'C', 'BABA', 'BA', 'HLF', 'CLDR', 'XOM', 'UPS', 'CRM', 'SD', 'CHTR', 'KO', 'QCOM', 'AVGO', 'ABT', 'PEP', 'SHY', 'ROP', 'NAV', 'BMY', 'GS', 'V', 'CRM', 'BIIB', 'SBAC', 'BSX']
2020-06-30 00:00:00: ['XELA', 'SPG', 'MSFT', 'GE', 'META', 'UNH', 'OXY', 'SBUX', 'CMCSA', 'JNJ', 'LNG', 'AIU', 'PG', 'TMO', 'V', 'SPY', 'META', 'MA', 'V', 'JPM', 'NWL', 'OXY', 'KHC', 'MA', 'JPM', 'WES', 'META', 'FI', 'UNH', 'V', 'CZR', 'ADBE', 'VOO', 'EW', 'XRX', 'BAX', 'CLDR', 'VRM', 'AMT', 'CHTR', 'SD', 'COST', 'JNJ', 'AAPL', 'CCI', 'NAV', 'PYPL', 'JPM', 'BAC', 'NKE', 'HLF', 'PG', 'BK', 'MA', 'INTU', 'WFC', 'CRM', 'CHTR', 'ADBE', 'V', 'JPM', 'INTC', 'C', 'UPS', 'CME', 'INO', 'MDLZ', 'EBAY', 'BABA', 'NFLX', 'ADBE', 'GOOGL', 'CRM', 'DIS', 'CRM', 'CSCO', 'AVGO', 'BAC', 'C', 'AMZN', 'XOM', 'NFLX', 'V', 'ATVI', 'DK', 'WFC', 'QCOM', 'FI', 'ZEN']
2020-09-30 00:00:00: ['AAPL', 'MSFT', 'GE', 'META', 'MSFT', 'INTC', 'SBUX', 'AAPL', 'TSLA', 'MSFT', 'LNG', 'OXY', 'AIU', 'NWL', 'DIS', 'V', 'HLF', 'JNJ', 'PG', 'XRX', 'MA', 'UNH', 'SD', 'NAV', 'MA', 'V', 'SPY', 'JPM', 'META', 'CHTR', 'CLDR', 'ADBE', 'MA', 'AMGN', 'C', 'MDT', 'VZ', 'MS', 'PFE', 'BABA', 'MRK', 'PYPL', 'NFLX', 'JNJ', 'VOO', 'CME', 'ADBE', 'CCI', 'PG', 'VRM', 'ICE', 'CRM', 'ABBV', 'TMUS', 'C', 'CRM', 'META', 'JPM', 'BMY', 'CVX', 'CRM', 'UPS', 'DIS', 'V', 'GM', 'HRI', 'CHTR', 'WFC', 'ADBE', 'HLT', 'ADBE', 'PYPL', 'BKNG', 'DIS', 'NFLX', 'SPY', 'INTC', 'A', 'EPD', 'BAC', 'INTU', 'WBT', 'PFE', 'WFC', 'ADI', 'NXPI', 'KO', 'GM', 'MA', 'CVI', 'ABT', 'DK']
2020-12-31 00:00:00: ['AAPL', 'MSFT', 'GE', 'TSLA', 'META', 'META', 'AAPL', 'MSFT', 'SBUX', 'LNG', 'UNH', 'BHC', 'AIU', 'SD', 'CMCSA', 'JNJ', 'V', 'NWL', 'V', 'PG', 'MA', 'SPY', 'OXY', 'MA', 'META', 'QCOM', 'PYPL', 'UNH', 'NKE', 'ADBE', 'HLF', 'UNH', 'XRX', 'WISH', 'TXN', 'NAV', 'CLDR', 'MS', 'PM', 'DAN', 'INTC', 'VZ', 'MRK', 'NFLX', 'TWTR', 'VOO', 'ABBV', 'CHTR', 'JNJ', 'TMUS', 'BMY', 'JPM', 'UBER', 'NOW', 'MDT', 'ABBV', 'CVX', 'BKNG', 'V', 'ADBE', 'PG', 'NFLX', 'SPY', 'BABA', 'WFC', 'DIS', 'BMY', 'UNP', 'CRM', 'DIS', 'WBT', 'PYPL', 'AMZN', 'MU', 'C', 'HRI', 'MA', 'UPS', 'WFC', 'META', 'CHTR', 'QCOM', 'CME', 'NKE', 'BAC', 'KO', 'ICE', 'INTU', 'VZ', 'AMZN', 'ADBE', 'VRM', 'CRM', 'CCK', 'SQ', 'FIS', 'PFE', 'INTC', 'MDLZ', 'ADI', 'GM', 'DK']
2021-03-31 00:00:00: ['AAPL', 'GE', 'MSFT', 'META', 'MSFT', 'GLD', 'AAPL', 'FE', 'EVFM', 'JNJ', 'LNG', 'SD', 'V', 'CMCSA', 'SPY', 'V', 'MA', 'PG', 'MA', 'META', 'CRM', 'BHC', 'XOS', 'INTC', 'AIU', 'PYPL', 'MA', 'NWL', 'BABA', 'WISH', 'PYPL', 'DIS', 'MA', 'HLF', 'NKE', 'DPZ', 'MDT', 'VOO', 'V', 'V', 'ADBE', 'CVX', 'BABA', 'JPM', 'MRK', 'A', 'ABBV', 'NFLX', 'VZ', 'JNJ', 'QCOM', 'XRX', 'UNH', 'WFC', 'CMG', 'HIPO', 'DAN', 'ADBE', 'NFLX', 'TMUS', 'UBER', 'CPRI', 'UNH', 'NAV', 'CRM', 'BAC', 'DIS', 'BMY', 'V', 'HLT', 'CLDR', 'NOW', 'BKNG', 'UPS', 'HRI', 'CRM', 'MU', 'W', 'PG', 'NFLX', 'META', 'INTU', 'WBT', 'CHTR', 'OPAD', 'CMCSA', 'CME', 'SNOW', 'XOM', 'SONO', 'C', 'KO', 'MDLZ', 'ICE', 'UNH', 'SQ', 'PFE', 'KPLT', 'SONO', 'MDLZ', 'SNOW', 'KO', 'UNH', 'AVGO', 'ABBV', 'BABA', 'DIS', 'QSR', 'ACN', 'ABT', 'AESC', 'SNX', 'AMZN', 'DK']
2021-06-30 00:00:00: ['AAPL', 'GE', 'META', 'MSFT', 'AAPL', 'FE', 'SD', 'JNJ', 'OXY', 'V', 'LNG', 'V', 'SPY', 'V', 'BABA', 'META', 'MA', 'PG', 'MA', 'MA', 'PYPL', 'NKE', 'BHC', 'V', 'MA', 'MSFT', 'SPY', 'BABA', 'CRM', 'NWL', 'KPLT', 'UNH', 'AMGN', 'TXN', 'ACN', 'VOO', 'NFLX', 'MDT', 'CRM', 'VOO', 'GLD', 'BABA', 'ADBE', 'DPZ', 'QCOM', 'UNH', 'MRK', 'JPM', 'EXPE', 'VRM', 'CVX', 'BABA', 'ABBV', 'WFC', 'V', 'VZ', 'JNJ', 'TMUS', 'META', 'META', 'NOW', 'PSFE', 'SPY', 'DAN', 'NFLX', 'XRX', 'UPS', 'BAC', 'UBER', 'NAV', 'WBT', 'CHTR', 'CLDR', 'BMY', 'IEMG', 'MA', 'BKNG', 'AIU', 'DIS', 'PG', 'HRI', 'INTU', 'PSFE', 'CHTR', 'CME', 'CMCSA', 'SNOW', 'KO', 'ICE', 'QCOM', 'BABA', 'XOS', 'HLT', 'UNH', 'KO', 'C', 'W', 'MDLZ', 'SQ', 'ABBV', 'NKE', 'AVGO', 'AMZN', 'EFA', 'SPOT', 'AESC', 'MRK', 'ACN', 'EPD', 'V', 'GM', 'NXPI', 'V', 'PEP', 'ABT', 'MDLZ', 'CRM', 'GPOR', 'DK', 'EPD', 'ADBE', 'ABNB', 'GM', 'CNDT', 'MMC']
2021-09-30 00:00:00: ['AAPL', 'CZOO', 'SD', 'META', 'MSFT', 'AAPL', 'GLD', 'EXPE', 'V', 'FE', 'GE', 'JPM', 'JNJ', 'SPY', 'UNH', 'OXY', 'V', 'PG', 'PG', 'MA', 'META', 'META', 'MDLZ', 'MA', 'V', 'BABA', 'V', 'VOO', 'UNH', 'VOO', 'BHC', 'DPZ', 'META', 'MA', 'AMGN', 'NKE', 'NWL', 'PYPL', 'PFE', 'CRM', 'WFC', 'INTU', 'BABA', 'UNH', 'ABBV', 'CVX', 'JPM', 'META', 'VZ', 'CRM', 'ELV', 'SWX', 'LNG', 'ACN', 'TSM', 'QCOM', 'JNJ', 'GS', 'TMUS', 'ABBV', 'WMT', 'ADBE', 'BAC', 'ELV', 'HRI', 'V', 'SPY', 'TWTR', 'BABA', 'WBT', 'UPS', 'PG', 'BMY', 'VSCO', 'IEMG', 'V', 'DAN', 'V', 'META', 'CLDR', 'CHTR', 'QSR', 'DIS', 'DIS', 'KO', 'INTU', 'BKNG', 'UBER', 'SNOW', 'XRX', 'NFLX', 'QCOM', 'NWS', 'C', 'CVS', 'HLT', 'CMCSA', 'XOM', 'BABA', 'ATIP', 'ICE', 'PSFE', 'CME', 'ZM', 'GPK', 'SNOW', 'KO', 'VTI', 'EFA', 'MDLZ', 'AMZN', 'ACN', 'AVGO', 'SONO', 'MMC', 'FUBO', 'WGS', 'MA', 'AESC', 'ABBV', 'PEP', 'CNX', 'USB', 'ABT', 'NKE', 'MRK']
2021-12-31 00:00:00: ['AAPL', 'PG', 'INTC', 'MSFT', 'CP', 'CZOO', 'SD', 'AAPL', 'MDLZ', 'FE', 'JPM', 'BABA', 'UNH', 'OXY', 'SPY', 'JNJ', 'VOO', 'PG', 'GLD', 'AMGN', 'UNP', 'V', 'MA', 'UNH', 'V', 'META', 'DIS', 'BHC', 'CMCSA', 'TWTR', 'VOO', 'LNG', 'NWL', 'ADBE', 'ACN', 'MA', 'BABA', 'QQQ', 'ABBV', 'C', 'CRM', 'NKE', 'SWX', 'CVX', 'INTU', 'QCOM', 'HUM', 'WFC', 'ASTR', 'VZ', 'ATVI', 'GE', 'PYPL', 'HRI', 'JPM', 'C', 'JNJ', 'DPZ', 'GS', 'INTU', 'ADBE', 'WBT', 'SPY', 'UPS', 'DIS', 'CRM', 'NSP', 'V', 'PG', 'KO', 'DAN', 'ADBE', 'TMUS', 'BAC', 'TSM', 'BMY', 'UNH', 'UBER', 'NSC', 'IVV', 'ABBV', 'SNOW', 'XRX', 'V', 'BSX', 'V', 'UNH', 'FI', 'BKNG', 'GOOGL', 'GOOGL', 'EFA', 'NFLX', 'SQ', 'SNOW', 'DIS', 'CHTR', 'SPY', 'AVGO', 'TMUS', 'ACN', 'UBER', 'VTI', 'CRM', 'SNOW', 'ICE', 'CVS', 'UBER', 'CME', 'KO', 'QSR', 'EPD', 'AMZN', 'AMZN', 'MCK', 'ABBV', 'MDLZ', 'AESC', 'CMCSA', 'AVGO', 'MMC', 'PEP', 'ABT', 'IVW', 'BAC', 'NKE', 'AMZN', 'RIVN', 'QCOM', 'GM']
2022-03-31 00:00:00: ['AAPL', 'PG', 'INTC', 'META', 'IFF', 'MSFT', 'SD', 'CP', 'AAPL', 'MDLZ', 'BAC', 'XLE', 'FE', 'V', 'UNP', 'JNJ', 'BAC', 'UNH', 'VOO', 'SPY', 'MA', 'MSFT', 'BABA', 'JPM', 'PG', 'NFLX', 'V', 'DIS', 'MA', 'MSFT', 'LNG', 'CRM', 'VOO', 'BKNG', 'UNH', 'TMO', 'NVDA', 'QQQ', 'BABA', 'META', 'NWL', 'VZ', 'INTU', 'META', 'META', 'SWX', 'ABBV', 'CI', 'BHC', 'BABA', 'C', 'JNJ', 'CVX', 'V', 'GS', 'QCOM', 'SPY', 'V', 'TMUS', 'KO', 'UPS', 'JPM', 'ATVI', 'C', 'PG', 'TSM', 'ACN', 'BAC', 'HRI', 'AVGO', 'V', 'WBT', 'AMZN', 'VOO', 'CME', 'MA', 'INTU', 'ABBV', 'TMUS', 'CVS', 'PNC', 'GOOGL', 'NKE', 'UBER', 'KO', 'AVGO', 'ZEN', 'C', 'BAC', 'NSC', 'NSP', 'EFA', 'DIS', 'VTI', 'FCX', 'DAN', 'TSM', 'UNH', 'EPD', 'PXD', 'CHTR', 'DPZ', 'MDLZ', 'PEP', 'ACN', 'MMC', 'ADBE', 'XRX', 'TJX', 'CMCSA', 'AMZN', 'ADI', 'AMZN', 'EPD', 'ABNB', 'SNOW', 'AMZN', 'ADBE', 'SQ', 'AXP', 'ABT', 'IVW', 'SNX', 'MRK', 'ILMN']
2022-06-30 00:00:00: ['AAPL', 'PG', 'CP', 'SD', 'IFF', 'MDLZ', 'AMZN', 'AMZN', 'XLE', 'MSFT', 'LNG', 'MSFT', 'AAPL', 'TMUS', 'DIS', 'RIVN', 'BAC', 'FE', 'META', 'V', 'JPM', 'JNJ', 'AMZN', 'VOO', 'SPY', 'PG', 'MA', 'V', 'UNH', 'MA', 'ABBV', 'WBD', 'TSLA', 'DIS', 'VOO', 'DIS', 'BLCO', 'BABA', 'NWL', 'QQQ', 'V', 'MSFT', 'SWX', 'JNJ', 'BABA', 'INTU', 'TMUS', 'CRM', 'ACN', 'NVDA', 'CNXC', 'META', 'SHY', 'GS', 'MA', 'CSX', 'SPY', 'C', 'PG', 'UPS', 'CCI', 'CL', 'QCOM', 'JPM', 'WBT', 'DPZ', 'TSM', 'CVX', 'CVX', 'TMUS', 'BHC', 'V', 'ABBV', 'NFLX', 'NKE', 'KO', 'CVS', 'SPGI', 'BKNG', 'BAC', 'EFA', 'INTU', 'CME', 'KO', 'TMO', 'HRI', 'CVE', 'META', 'UNH', 'WGS', 'PEP', 'ADI', 'MDLZ', 'C', 'TSM', 'VTI', 'AVGO', 'DAN', 'GPK', 'MMC', 'V', 'CNX', 'ACN', 'ABT', 'EPD', 'CHTR', 'MRK', 'XRX', 'CMCSA', 'DIS', 'WBD', 'ADBE', 'PYPL']
2022-09-30 00:00:00: ['AAPL', 'PG', 'MSFT', 'INTC', 'AMZN', 'MSFT', 'LNG', 'AMZN', 'SD', 'MDLZ', 'AMZN', 'IFF', 'TWTR', 'AAPL', 'TSLA', 'RIVN', 'TMUS', 'CP', 'DIS', 'JNJ', 'AMZN', 'FE', 'V', 'BAC', 'JPM', 'CCK', 'SPY', 'PG', 'V', 'MA', 'MA', 'VOO', 'VOO', 'TJX', 'CSX', 'GPN', 'UNH', 'GOOG', 'HLT', 'SPY', 'GOOG', 'ABBV', 'BLCO', 'BABA', 'GOOGL', 'DIS', 'TMUS', 'JNJ', 'INTU', 'V', 'CRM', 'META', 'SHY', 'QQQ', 'NWL', 'PYPL', 'UNH', 'SPY', 'NOW', 'GLD', 'UNP', 'UPS', 'META', 'BABA', 'SWX', 'NVDA', 'CVX', 'PG', 'JPM', 'GS', 'CCI', 'KO', 'CVX', 'META', 'MA', 'MSFT', 'BABA', 'ACN', 'CHNG', 'QCOM', 'CVS', 'BSX', 'BAC', 'BABA', 'CNXC', 'ABBV', 'TSM', 'KO', 'TMUS', 'GPK', 'HRI', 'C', 'DD', 'TTWO', 'V', 'FERG', 'C', 'QSR', 'BHC', 'MDLZ', 'MMC', 'BKNG', 'VTI', 'SLV', 'PEP', 'V']
2023-03-31 00:00:00: ['AAPL', 'AAPL', 'MDLZ', 'GOOGL', 'LNG', 'ILMN', 'AMZN', 'AMZN', 'SD', 'IFF', 'GOOGL', 'AAPL', 'J', 'UNH', 'MSFT', 'GOOG', 'GOOG', 'NVDA', 'TSLA', 'GEHC', 'FE', 'NVDA', 'GLD', 'JNJ', 'VOO', 'AMZN', 'SPY', 'CCK', 'BAC', 'SPY', 'V', 'PG', 'MA', 'UNH', 'ELV', 'V', 'VOO', 'FCNCA', 'V', 'BLCO', 'UNP', 'ELV', 'V', 'GOOG', 'GOOG', 'PDBC', 'UNH', 'MA', 'CVX', 'MA', 'META', 'DIS', 'AMD', 'TMUS', 'TMUS', 'MA', 'UNH', 'SLV', 'NWL', 'JNJ', 'CRM', 'SPY', 'KO', 'UPS', 'JPM', 'DIS', 'BABA', 'GPK', 'NYCB', 'PG', 'AMD', 'HRI', 'WMT', 'LLY', 'C', 'CNXC', 'NFLX', 'GS', 'CVX', 'BABA', 'QCOM', 'ABBV', 'V', 'BABA', 'AVGO', 'SWX', 'CRM', 'BAC', 'CRM', 'KO', 'MDLZ', 'BHC', 'GOOGL', 'RIO', 'EFA', 'C', 'OIH', 'VTI', 'BAC']
2023-06-30 00:00:00: ['AAPL', 'AMZN', 'MSFT', 'MDLZ', 'GOOGL', 'ILMN', 'SD', 'AAPL', 'AMZN', 'ATVI', 'IFF', 'MSFT', 'NVDA', 'NVDA', 'AMZN', 'AAPL', 'NVDA', 'FE', 'CCK', 'NVDA', 'GEHC', 'GOOGL', 'GOOGL', 'AMZN', 'JNJ', 'SPY', 'VOO', 'J', 'BLCO', 'V', 'MA', 'NVDA', 'PG', 'LLY', 'BAC', 'UNP', 'J', 'VOO', 'V', 'META', 'GOOG', 'GOOG', 'CVX', 'UNH', 'V', 'FCNCA', 'ELV', 'SHC', 'GLD', 'KO', 'TMUS', 'AVGO', 'UNH', 'NWL', 'PDBC', 'FDX', 'LLY', 'NYCB', 'CHTR', 'SLV', 'SPY', 'JNJ', 'AMD', 'MA', 'JPM', 'FHN', 'DIS', 'UPS', 'AAP', 'BAC', 'BHC', 'AVGO', 'UBER', 'PG', 'RTX', 'HRI', 'ELV', 'CI', 'TMUS', 'DAN', 'ATVI', 'CRM', 'ELV', 'MA', 'TSM', 'CVX', 'MDLZ', 'QCOM', 'V', 'ACN', 'HCA', 'NOW', 'C', 'KO', 'UBER', 'VTI', 'EFA']
'''
# Out:
# "\nTop 10th percentile of stocks in each quarter based on portfolio tilt:\n2001-12-31 00:00:00: ['C', 'NXTL', 'TWX', 'EIX', 'LNC', 'FE', 'ELN', 'T', 'T', 'PVN', 'IBM', 'PVN', 'COST', 'VIAV', 'PFE', 'TGNA', 'HD', 'STI', 'FCEL', 'SFE', 'MRK', 'AKAM', 'FDC', 'DD', 'CEM', 'BEV', 'GPS', 'NEOL', 'FE', 'INTC', 'WFC', 'JAVA', 'MO', 'EVRG', 'INTC', 'DD', 'DELL', 'CCI', 'FALC', 'ITWO', 'BLS', 'DOV', 'MTB', 'VIAV', 'SGP', 'DNB', 'ITWO', 'SILI', 'PARA', 'PACW', 'DD', 'TXN', 'DIS', 'ODP', 'TT', 'JNY', 'JPM', 'MCD', 'AWE', 'NHI', 'PARA', 'HRB', 'BA', 'WPO', 'PVN', 'G', 'TZH', 'CMTN', 'DNB', 'AMAT', 'OSI', 'QQQ', 'Q', 'XLNX', 'PAYX', 'ALL', 'MCO', 'TGT', 'GL', 'GPS', 'MXIM', 'CRAY', 'WM']\n2002-09-30 00:00:00: ['WINT', 'C', 'C', 'T', 'T', 'AIG', 'PCG', 'INTC', 'PFE', 'ADP', 'TGNA', 'BKS', 'STI', 'ETS', 'COST', 'CSCO', 'FRTX', 'INTC', 'FALC', 'DIS', 'JNJ', 'MCD', 'AMAT', 'S', 'FRTX', 'BEV', 'MDC', 'SGP', 'GPS', 'SPY', 'ACF', 'SILI', 'MO', 'WFC', 'TXN', 'POG', 'LVLT', 'KRB', 'MRK', 'PACW', 'MTB', 'RT
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
# Out:
# /Users/ishaanpoojari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/ishaanpoojari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
initial_holdings = ['C', 'NXTL', 'TWX', 'EIX', 'LNC', 'FE', 'ELN', 'T', 'T', 'PVN', 'IBM', 'PVN', 'COST', 'VIAV', 'PFE', 'TGNA', 'HD', 'STI', 'FCEL', 'SFE', 'MRK', 'AKAM', 'FDC', 'DD', 'CEM', 'BEV', 'GPS', 'NEOL', 'FE', 'INTC', 'WFC', 'JAVA', 'MO', 'EVRG', 'INTC', 'DD', 'DELL', 'CCI', 'FALC', 'ITWO', 'BLS', 'DOV', 'MTB', 'VIAV', 'SGP', 'DNB', 'ITWO', 'SILI', 'PARA', 'PACW', 'DD', 'TXN', 'DIS', 'ODP', 'TT', 'JNY', 'JPM', 'MCD', 'AWE', 'NHI', 'PARA', 'HRB', 'BA', 'WPO', 'PVN', 'G', 'TZH', 'CMTN', 'DNB', 'AMAT', 'OSI', 'QQQ', 'Q', 'XLNX', 'PAYX', 'ALL', 'MCO', 'TGT', 'GL', 'GPS', 'MXIM', 'CRAY', 'WM']

def fetch_stock_data(tickers):
    data = yf.download(tickers, start="2001-12-31", end="2005-12-31")
    data = data['Adj Close'].pct_change().dropna()  # Using Adjusted Close prices
    return data

stock_data = fetch_stock_data(initial_holdings)
# Out:
# [*********************100%%**********************]  71 of 71 completed
#
# 25 Failed downloads:
# ['PACW', 'MXIM', 'XLNX', 'CRAY', 'FDC', 'SFE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['WPO', 'CMTN', 'Q', 'TZH', 'NXTL', 'ITWO', 'ELN', 'SILI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2001-12-31 -> 2005-12-31)')
# ['G', 'JAVA', 'NEOL', 'DELL', 'OSI', 'AWE', 'DNB', 'STI', 'SGP', 'PVN', 'CEM']: Exception("%ticker%: Data doesn't exist for startDate = 1009774800, endDate = 1136005200")
# /var/folders/74/ln4b1v9s2td760h27rw373p80000gn/T/ipykernel_3077/3991377795.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data = data['Adj Close'].pct_change().dropna()  # Using Adjusted Close prices

# %%
import wrds
db = wrds.Connection(wrds_username='user2294')
# Out:
# Loading library list...
# Done

# %%
ticker_str = "', '".join(initial_holdings)

query = f"""
SELECT a.date, b.ticker, a.ret
FROM crsp.dsf AS a
JOIN crsp.dsenames AS b ON a.permno = b.permno
WHERE b.ticker IN ('{ticker_str}')
AND a.date >= '2001-12-31' AND a.date <= '2005-12-31'
AND b.namedt <= a.date AND a.date <= b.nameendt
ORDER BY a.date, b.ticker;
"""

data = db.raw_sql(query)
# data['date'] = pd.to_datetime(data['date'])
# data.set_index('date', inplace=True)
# data.pivot(columns='ticker', values='ret').fillna(0, inplace=True)
data['date'] = pd.to_datetime(data['date'])
pivot_data = data.pivot(index='date', columns='ticker', values='ret').fillna(0)

# %%
data
# Out:
#             date ticker       ret
# 0     2001-12-31   AKAM -0.010000
# 1     2001-12-31    ALL -0.004725
# 2     2001-12-31   AMAT -0.040899
# 3     2001-12-31    AWE -0.015079
# 4     2001-12-31     BA -0.008184
# ...          ...    ...       ...
# 62195 2005-12-30    TXN -0.010491
# 62196 2005-12-30    WFC -0.003647
# 62197 2005-12-30     WM -0.004121
# 62198 2005-12-30    WPO  0.000000
# 62199 2005-12-30   XLNX  0.000397
#
# [62200 rows x 3 columns]

# %%
pivot_data
# Out:
# ticker          AKAM       ALL      AMAT       AWE        BA       BEV  \
# date
# 2001-12-31 -0.010000 -0.004725 -0.040899 -0.015079 -0.008184 -0.011494
# 2002-01-02 -0.011785 -0.015134  0.039152  0.004871 -0.017535 -0.052326
# 2002-01-03  0.039182 -0.018379  0.091673  0.001385  0.017060  0.000000
# 2002-01-04  0.018033  0.003376 -0.005935 -0.056017  0.041548  0.036810
# 2002-01-07 -0.064412  0.011013 -0.010615 -0.018315  0.015857 -0.039053
# ...              ...       ...       ...       ...       ...       ...
# 2005-12-23 -0.016153 -0.003095  0.003819  0.000000  0.002384  0.006844
# 2005-12-27  0.008458 -0.003835 -0.011413  0.000000 -0.013428 -0.006797
# 2005-12-28  0.001480 -0.001100  0.001099  0.000000  0.006097  0.007699
# 2005-12-29 -0.014778 -0.003487 -0.008237  0.000000  0.003100 -0.002547
# 2005-12-30 -0.003500 -0.004236 -0.006644  0.000000 -0.013206 -0.006809
#
# ticker           BLS         C       CCI       CEM  ...         T       TGT  \
# ...

# %%
data.loc["2002-1-23"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 data.loc["2002-1-23"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
# ...

# %%
print(data.dtypes)
print("Pivot data:")
print(pivot_data.dtypes)

allPivots = True
for col in pivot_data.columns:
    if pivot_data[col].dtype != 'float64':
        allPivots = False
if allPivots:
    print("All pivots are float64")
else:
    print("Not all pivots are float64")
# Out:
# date      datetime64[ns]
# ticker            object
# ret              float64
# dtype: object
# Pivot data:
# ticker
# AKAM    float64
# ALL     float64
# AMAT    float64
# AWE     float64
# BA      float64
#          ...
# TZH     float64
# WFC     float64
# WM      float64
# WPO     float64
# XLNX    float64
# Length: 66, dtype: object
# All pivots are float64

# %%
# Check for missing data
print(data.isna().sum())
print(data.head())
# Out:
# date      0
# ticker    0
# ret       1
# dtype: int64
#         date ticker       ret
# 0 2001-12-31   AKAM -0.010000
# 1 2001-12-31    ALL -0.004725
# 2 2001-12-31   AMAT -0.040899
# 3 2001-12-31    AWE -0.015079
# 4 2001-12-31     BA -0.008184

# %%
print(data.head())
print("Data shape:", data.shape)
# Out:
#         date ticker       ret
# 0 2001-12-31   AKAM -0.010000
# 1 2001-12-31    ALL -0.004725
# 2 2001-12-31   AMAT -0.040899
# 3 2001-12-31    AWE -0.015079
# 4 2001-12-31     BA -0.008184
# Data shape: (62200, 3)

# %%
from gym import Env
from gym.spaces import Box


class StockPortfolioEnv(Env):
    def __init__(self, df):
        super(StockPortfolioEnv, self).__init__()
        self.df = df
        self.n_assets = len(df.columns)
        self.action_space = Box(low=0, high=1, shape=(self.n_assets,), dtype=np.float32)
        self.observation_space = Box(low=-np.inf, high=np.inf, shape=(self.n_assets,), dtype=np.float32)
        self.initial_weights = np.array([1.0 / self.n_assets] * self.n_assets)

    def reset(self):
        self.current_step = 0
        self.portfolio_returns = []
        self.current_weights = self.initial_weights.copy()
        initial_obs = self.df.iloc[0].values
        return initial_obs.astype(np.float32)  

    def step(self, action):
        self.current_weights = action / np.sum(action)
        current_returns = self.df.iloc[self.current_step].values
        portfolio_return = np.dot(current_returns, self.current_weights)
        self.portfolio_returns.append(portfolio_return)

        sharpe_ratio = self.calculate_sharpe_ratio()

        reward = sharpe_ratio
        self.current_step += 1
        done = self.current_step >= len(self.df)-1
        next_obs = self.df.iloc[self.current_step % len(self.df)].values
        return next_obs.astype(np.float32), reward, done, {'sharpe_ratio': sharpe_ratio}  

    def calculate_sharpe_ratio(self):
        if len(self.portfolio_returns) > 1:
            mean_returns = np.mean(self.portfolio_returns)
            std_returns = np.std(self.portfolio_returns)
            if std_returns > 0:
                return mean_returns / std_returns
            else:
                return 0
        return 0

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Portfolio Returns: {self.portfolio_returns[-1] if self.portfolio_returns else 'N/A'}")
        print(f'Current Weights: {self.current_weights}')

# %%
from stable_baselines3 import PPO

env = StockPortfolioEnv(pivot_data)

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 14.2     |
# | time/              |          |
# |    fps             | 872      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 9.99        |
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017306482 |
# |    clip_fraction        | 0.155       |
# ...

# %%
def evaluate_model(env, model, print_each_quarter=True):
    obs = env.reset() 
    done = False
    total_days = len(env.df)
    quarterly_steps = total_days // 4
    all_rewards = []

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        all_rewards.append(reward)

        if (env.current_step + 1) % quarterly_steps == 0 or done:
            current_date = env.df.index[env.current_step]
            if print_each_quarter:
                print(f"Quarter Ending {current_date.strftime('%Y-%m-%d')}: Sharpe Ratio: {info['sharpe_ratio']:.4f}")
                print(f"End of Quarter Portfolio Weights: {env.current_weights}")  # Accessing weights directly from the environment
            if done:
                break

    initial_sharpe = all_rewards[0] if all_rewards else 0  # Safeguard against empty list
    final_sharpe = all_rewards[-1] if all_rewards else 0
    improvement = ((final_sharpe - initial_sharpe) / abs(initial_sharpe)) * 100 if initial_sharpe != 0 else 0
    print(f"Initial Sharpe Ratio: {initial_sharpe:.4f}, Final Sharpe Ratio: {final_sharpe:.4f}")
    print(f"Improvement in Sharpe Ratio: {improvement:.2f}%")

    return initial_sharpe, final_sharpe, improvement

# %%
initial_sharpe, final_sharpe, improvement = evaluate_model(env, model)
# Out:
# Quarter Ending 2002-12-30: Sharpe Ratio: -0.0167
# End of Quarter Portfolio Weights: [9.6929427e-03 8.6724600e-03 0.0000000e+00 0.0000000e+00 8.2969824e-03
#  1.1002856e-03 3.0773651e-02 3.0821862e-02 2.6236286e-02 0.0000000e+00
#  1.7440919e-02 1.8755576e-02 1.0782995e-02 0.0000000e+00 0.0000000e+00
#  1.0320692e-02 0.0000000e+00 0.0000000e+00 5.9326477e-02 2.7244290e-02
#  1.6841255e-02 2.1002229e-02 3.0549865e-02 0.0000000e+00 8.0456370e-03
#  5.0629787e-03 6.5165339e-03 4.1827343e-02 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 4.7465597e-05 4.2700522e-02 0.0000000e+00
#  2.6766066e-02 5.2130453e-02 6.0257591e-02 4.4101145e-02 4.1732557e-02
#  1.3892571e-03 0.0000000e+00 4.9496992e-03 1.7735483e-02 0.0000000e+00
#  0.0000000e+00 8.0366023e-03 0.0000000e+00 9.9548511e-03 2.5451647e-02
#  3.5873327e-02 7.8818882e-03 2.9359573e-02 1.1234760e-02 0.0000000e+00
#  2.3880592e-02 0.0000000e+00 4.7403637e-02 0.0000000e+00 0.0000000e+00
# ...

# %%
def multiple_trials(n_trials, env, total_timesteps=20000):
    improvements = []
    final_sharpes = []
    initial_sharpes = []

    for i in range(n_trials):
        model = PPO("MlpPolicy", env, verbose=0)  # Initialize a new model each trial
        model.learn(total_timesteps=total_timesteps)
        
        initial_sharpe, final_sharpe, improvement = evaluate_model(env, model, print_each_quarter=False)
        
        improvements.append(improvement)
        final_sharpes.append(final_sharpe)
        initial_sharpes.append(initial_sharpe)
        
        print(f"Trial {i+1}: Initial Sharpe: {initial_sharpe:.4f}, Final Sharpe: {final_sharpe:.4f}, Improvement: {improvement:.2f}%")

    return initial_sharpes, final_sharpes, improvements

n_trials = 10
initial_sharpes, final_sharpes, improvements = multiple_trials(n_trials, env)
# Out:
# /Users/ishaanpoojari/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Initial Sharpe Ratio: 0.0000, Final Sharpe Ratio: 0.1161
# Improvement in Sharpe Ratio: 0.00%
# Trial 1: Initial Sharpe: 0.0000, Final Sharpe: 0.1161, Improvement: 0.00%
# Initial Sharpe Ratio: 0.0000, Final Sharpe Ratio: 0.1849
# Improvement in Sharpe Ratio: 0.00%
# Trial 2: Initial Sharpe: 0.0000, Final Sharpe: 0.1849, Improvement: 0.00%
# Initial Sharpe Ratio: 0.0000, Final Sharpe Ratio: 0.1468
# Improvement in Sharpe Ratio: 0.00%
# Trial 3: Initial Sharpe: 0.0000, Final Sharpe: 0.1468, Improvement: 0.00%
# Initial Sharpe Ratio: 0.0000, Final Sharpe Ratio: 0.1080
# Improvement in Sharpe Ratio: 0.00%
# ...

# %%
import matplotlib.pyplot as plt

def plot_results(initial_sharpes, final_sharpes, improvements):
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.hist(improvements, bins=10, color='blue', alpha=0.7)
    plt.title("Improvements in Sharpe Ratio")
    plt.xlabel("Improvement (%)")
    plt.ylabel("Frequency")

    plt.subplot(1, 2, 2)
    plt.scatter(initial_sharpes, final_sharpes, color='red')
    plt.title("Initial vs Final Sharpe Ratios")
    plt.xlabel("Initial Sharpe Ratio")
    plt.ylabel("Final Sharpe Ratio")
    plt.axline([1, 1], slope=1, color="blue", linestyle="--")  

    plt.tight_layout()
    plt.show()

plot_results(initial_sharpes, final_sharpes, improvements)

# %%
def evaluate_model2(env, model, print_each_quarter=True):
    obs = env.reset()
    done = False
    all_rewards = []
    counter = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        all_rewards.append(reward)
        counter += 1

        # Only add to records after a few steps to allow the portfolio to 'warm up'
        if counter > 10: 
            all_rewards.append(reward)

        if done or (env.current_step + 1) % (len(env.df) // 4) == 0:
            current_date = env.df.index[env.current_step]
            if print_each_quarter or done:
                print(f"Quarter Ending {current_date.strftime('%Y-%m-%d')}: Sharpe Ratio: {info['sharpe_ratio']:.4f}")
                print(f"End of Quarter Portfolio Weights: {env.current_weights}")

    # Compute Sharpe ratios using all recorded rewards
    initial_sharpe = np.mean(all_rewards[:len(all_rewards)//4]) / np.std(all_rewards[:len(all_rewards)//4]) if len(all_rewards) > 1 else 0
    final_sharpe = np.mean(all_rewards) / np.std(all_rewards) if len(all_rewards) > 1 else 0
    improvement = ((final_sharpe - initial_sharpe) / abs(initial_sharpe) * 100) if initial_sharpe != 0 else 0

    print(f"Initial Sharpe Ratio: {initial_sharpe:.4f}, Final Sharpe Ratio: {final_sharpe:.4f}")
    print(f"Improvement in Sharpe Ratio: {improvement:.2f}%")

    return initial_sharpe, final_sharpe, improvement

# %%
def get_final_portfolio_weights(env, model):
    obs = env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = env.step(action)
    
    final_weights = env.current_weights
    stocks = env.df.columns
    portfolio_df = pd.DataFrame({'Stock': stocks, 'Weight': final_weights})
    return portfolio_df

final_portfolio_df = get_final_portfolio_weights(env, model)
final_portfolio_df
# Out:
#    Stock    Weight
# 0   AKAM  0.000000
# 1    ALL  0.006851
# 2   AMAT  0.000000
# 3    AWE  0.000000
# 4     BA  0.000000
# ..   ...       ...
# 61   TZH  0.023910
# 62   WFC  0.010217
# 63    WM  0.019649
# 64   WPO  0.001717
# 65  XLNX  0.046207
#
# [66 rows x 2 columns]

# %%
def fetch_prices_from_wrds(stocks, date):
    formatted_stocks = ','.join([f"'{stock}'" for stock in stocks])
    query = f"""
    SELECT a.permno, b.ticker, a.prc AS price, b.caldt AS date
    FROM crsp.dsf AS a
    JOIN crsp.dsenames AS b ON a.permno = b.permno
    WHERE b.ticker IN ({formatted_stocks}) AND b.caldt = '{date}'
    AND b.namedt <= '{date}' AND '{date}' <= b.nameendt
    ORDER BY b.ticker;
    """
    try:
        prices = db.raw_sql(query)
        return prices
    except Exception as e:
        print(f"An error occurred: {e}")
        return pd.DataFrame()  # Return an empty DataFrame on error

date_of_interest = '2023-09-30'
prices_df = fetch_prices_from_wrds(final_portfolio_df['Stock'], date_of_interest)
prices_df
# Out:
# An error occurred: (psycopg2.errors.UndefinedColumn) column b.caldt does not exist
# LINE 2:     SELECT a.permno, b.ticker, a.prc AS price, b.caldt AS da...
#                                                        ^
#
# [SQL:
#     SELECT a.permno, b.ticker, a.prc AS price, b.caldt AS date
#     FROM crsp.dsf AS a
#     JOIN crsp.dsenames AS b ON a.permno = b.permno
#     WHERE b.ticker IN ('AKAM','ALL','AMAT','AWE','BA','BEV','BLS','C','CCI','CEM','CMTN','COST','CRAY','DD','DELL','DIS','DNB','DOV','EIX','ELN','FALC','FCEL','FDC','FE','G','GL','GPS','HD','HRB','IBM','INTC','ITWO','JNY','JPM','LNC','MCD','MCO','MO','MRK','MTB','MXIM','NEOL','NHI','NXTL','ODP','OSI','PACW','PAYX','PFE','PVN','Q','QQQ','SFE','SGP','SILI','STI','T','TGT','TT','TWX','TXN','TZH','WFC','WM','WPO','XLNX') AND b.caldt = '2023-09-30'
#     AND b.namedt <= '2023-09-30' AND '2023-09-30' <= b.nameendt
#     ORDER BY b.ticker;
#     ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# ...

# %%
def calculate_portfolio_return(portfolio_df, prices_df):
    # Merge the prices with the portfolio weights; make sure both 'ticker' and 'price' columns are correctly named
    merged_df = portfolio_df.merge(prices_df, left_on='Stock', right_on='ticker')
    merged_df['weighted_prc'] = merged_df['Weight'] * merged_df['price']  # Ensure the price column is named correctly

    total_portfolio_return = merged_df['weighted_prc'].sum()
    return total_portfolio_return

portfolio_return = calculate_portfolio_return(final_portfolio_df, prices_df)
print(f"Portfolio Return: {portfolio_return}")
# Out:
# RangeIndex(start=0, stop=0, step=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [98], in <cell line: 18>()
#      15     return total_portfolio_return
#      17 # Use the function
# ---> 18 portfolio_return = calculate_portfolio_return(final_portfolio_df, prices_df)
#      19 print(f"Portfolio Return: {portfolio_return}")
#
# Input In [98], in calculate_portfolio_return(portfolio_df, prices_df)
#       1 def calculate_portfolio_return(portfolio_df, prices_df):
#       2     # First, ensure the column names are correct
#       3     # Example column names are assumed as follows:
#    (...)
#       7
#       8     # Check column names in prices_df
#       9     print(prices_df.columns)  # This line will print the column names of prices_df
# ---> 11     merged_df = portfolio_df.merge(prices_df, left_on='Stock', right_on='ticker')  # Replace 'ticker' if necessary
# ...

# %%
def fetch_sp500_price(date):
    # Correct table name and column names based on actual schema
    query = f"""
    SELECT caldt, spindx
    FROM crsp.dsp500 
    WHERE caldt = '{date}'
    """
    try:
        price = db.raw_sql(query)
        return price.iloc[0]['spindx'] if not price.empty else None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

sp500_price = fetch_sp500_price(date_of_interest)

# %%
def calculate_portfolio_return(portfolio_df, prices_df):
    # Ensure that the price DataFrame is merged based on 'permno' if necessary or directly if tickers are used
    merged_df = portfolio_df.merge(prices_df, left_on='Stock', right_on='ticker')
    merged_df['weighted_prc'] = merged_df['Weight'] * merged_df['prc']
    
    total_portfolio_return = merged_df['weighted_prc'].sum()
    return total_portfolio_return

portfolio_return = calculate_portfolio_return(final_portfolio_df, prices_df)

# Assuming `sp500_price` is the return, not the price level; adjust as necessary based on the data specifics
performance_diff = (portfolio_return - sp500_price) / sp500_price * 100
print(f"Performance difference from S&P 500: {performance_diff:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [90], in <cell line: 9>()
#       6     total_portfolio_return = merged_df['weighted_prc'].sum()
#       7     return total_portfolio_return
# ----> 9 portfolio_return = calculate_portfolio_return(final_portfolio_df, prices_df)
#      11 # Assuming `sp500_price` is the return, not the price level; adjust as necessary based on the data specifics
#      12 performance_diff = (portfolio_return - sp500_price) / sp500_price * 100
#
# Input In [90], in calculate_portfolio_return(portfolio_df, prices_df)
#       1 def calculate_portfolio_return(portfolio_df, prices_df):
#       2     # Ensure that the price DataFrame is merged based on 'permno' if necessary or directly if tickers are used
# ----> 3     merged_df = portfolio_df.merge(prices_df, left_on='Stock', right_on='ticker')
# ...
